# %%
import numpy as np
import matplotlib.pyplot as plt

from run_job import run_qite
from qforte import Molecule, system_factory

# %%
cnot_path = '/home/vlita/Desktop/rsrch/2025_sqite/cnot/'

# %%
h6 = [('H', (0., 0., 0.)), 
    ('H', (0., 0., 1.0)),
    ('H', (0., 0., 2.0)), 
    ('H', (0., 0., 3.0)),
    ('H', (0., 0., 4.0)), 
    ('H', (0., 0., 5.0))]

mol = system_factory(build_type='psi4', mol_geometry=h6, basis='sto-6g', run_fci=True)
print(f'The HF energy from Psi4:                                     {mol.hf_energy:12.10f}')
print(f'The FCI energy from Psi4:                                    {mol.fci_energy:12.10f}')
# Out:
#  ==> Psi4 geometry <==
# -------------------------
# 0  1
# H  0.0  0.0  0.0
# H  0.0  0.0  1.0
# H  0.0  0.0  2.0
# H  0.0  0.0  3.0
# H  0.0  0.0  4.0
# H  0.0  0.0  5.0
# symmetry c1
# units angstrom
#
#   Memory set to   1.863 GiB by Python driver.
# The HF energy from Psi4:                                     -3.1560009293
# The FCI energy from Psi4:                                    -3.2576068321

# %%
SD_path = run_qite(
    mol,
    beta=11.1,
    db=0.1,
    expansion_type='SD',
    second_order=True,
    conv_thresh=1.0e-3,
    output_path=cnot_path)

# b_SD = [float(item) for item in h6_SD_beta]
# e_SD = [abs(float(item) - mol.fci_energy) for item in h6_SD_energy]
# p_SD = [int(item) for item in h6_SD_param]
# c_SD  = [int(item) for item in h6_SD_cnot]
# m_SD = [int(item) for item in h6_SD_measure]
# Out:
# -----------------------------------------------------
#      Quantum Imaginary Time Evolution Algorithm
# -----------------------------------------------------
#
#
#                  ==> QITE options <==
# -----------------------------------------------------------
# Computer Type:                            fci
# Trial reference state:                    |111111000000>
# Number of Hamiltonian Pauli terms:        919
# Trial state preparation method:           occupation_list
# Trotter order (rho):                      1
# Trotter number (m):                       1
# Use fast version of algorithm:            True
#
#
# Total imaginary evolution time (beta):    11.1
# Imaginary time step (db):                 0.1
#
#
# Use Folded Spectrum:                      False
#
#
# Use CIS Reference:                        False
#
#
# Use exact evolutoin:                      False
#
#
# Expansion type:                           SD
# Use DIIS:                                 False
# Max DIIS size:                            False
# Use selected pool:                        False
# x value threshold:                        1e-10
# Use sparse tensors to solve Sx = b:       False
#
#
# Use low memory mode:                      False
# Use 2nd order derivation of QITE:         True
# Do Quantum Lanczos                        False
#
#
#
#
# ==> Building expansion pool <==
#    beta           E(beta)     N(params)           N(CNOT)          N(measure)
# -------------------------------------------------------------------------------
#    0.000       -3.156000929           0                 0                   0
#    0.100       -3.178767752          51               834             1071078
#    0.200       -3.195605257         102              1668             1402970
#    0.300       -3.208213808         153              2502             1734862
#    0.400       -3.217776923         204              3336             2066754
#    0.500       -3.225122000         255              4170             2398646
#    0.600       -3.230832220         306              5004             2730538
#    0.700       -3.235322834         357              5838             3062430
#    0.800       -3.238892805         408              6672             3394322
#    0.900       -3.241759833         459              7506             3726214
#    1.000       -3.244084227         510              8340             4058106
#    1.100       -3.245985340         561              9174             4389998
#    1.200       -3.247552970         612             10008             4721890
#    1.300       -3.248855372         663             10842             5053782
#    1.400       -3.249944936         714             11676             5385674
#    1.500       -3.250862249         765             12510             5717566
#    1.600       -3.251639041         816             13344             6049458
#    1.700       -3.252300334         867             14178             6381350
#    1.800       -3.252866021         918             15012             6713242
#    1.900       -3.253352045         969             15846             7045134
#    2.000       -3.253771284        1020             16680             7377026
#    2.100       -3.254134212        1071             17514             7708918
#    2.200       -3.254449410        1122             18348             8040810
#    2.300       -3.254723954        1173             19182             8372702
#    2.400       -3.254963717        1224             20016             8704594
#    2.500       -3.255173598        1275             20850             9036486
#    2.600       -3.255357714        1326             21684             9368378
#    2.700       -3.255519535        1377             22518             9700270
#    2.800       -3.255662006        1428             23352            10032162
#    2.900       -3.255787633        1479             24186            10364054
#    3.000       -3.255898562        1530             25020            10695946
#    3.100       -3.255996635        1581             25854            11027838
#    3.200       -3.256083439        1632             26688            11359730
#    3.300       -3.256160347        1683             27522            11691622
#    3.400       -3.256228549        1734             28356            12023514
#    3.500       -3.256289081        1785             29190            12355406
#    3.600       -3.256342844        1836             30024            12687298
#    3.700       -3.256390629        1887             30858            13019190
#    3.800       -3.256433126        1938             31692            13351082
#    3.900       -3.256470940        1989             32526            13682974
#    4.000       -3.256504605        2040             33360            14014866
#    4.100       -3.256534590        2091             34194            14346758
#    4.200       -3.256561308        2142             35028            14678650
#    4.300       -3.256585124        2193             35862            15010542
#    4.400       -3.256606360        2244             36696            15342434
#    4.500       -3.256625303        2295             37530            15674326
# qite converged for convergence threshold 0.001 Hartree
#
#
#         Process name            Time (s)             Percent
#        =============       =============       =============
# Total evolution time              4.8310              100.00
#
#           Total Time              4.8310              100.00
#
#
#
#
#
#                         ==> QITE summary <==
# -----------------------------------------------------------
# Final QITE Energy:                         -3.2566253025
# Number of operators in pool:               51
# Number of classical parameters used:       2295
# Estimated classical memory usage (GB):     7.488000e-04
# Number of CNOT gates in deepest circuit:   37530
# Number of Pauli term measurements:         15674326

# %%
GSD_path = run_qite(
    mol,
    beta=2.0,
    db=0.1,
    expansion_type='GSD',
    low_memorySb=True,
    second_order=True,
    output_path=cnot_path)

# b_GSD = [float(item) for item in h6_GSD_beta]
# e_GSD = [abs(float(item) - mol.fci_energy) for item in h6_GSD_energy]
# p_GSD = [int(item) for item in h6_GSD_param]
# c_GSD  = [int(item) for item in h6_GSD_cnot]
# m_GSD = [int(item) for item in h6_GSD_measure]
# Out:
# -----------------------------------------------------
#      Quantum Imaginary Time Evolution Algorithm
# -----------------------------------------------------
#
#
#                  ==> QITE options <==
# -----------------------------------------------------------
# Computer Type:                            fci
# Trial reference state:                    |111111000000>
# Number of Hamiltonian Pauli terms:        919
# Trial state preparation method:           occupation_list
# Trotter order (rho):                      1
# Trotter number (m):                       1
# Use fast version of algorithm:            True
#
#
# Total imaginary evolution time (beta):    2.0
# Imaginary time step (db):                 0.1
#
#
# Use Folded Spectrum:                      False
#
#
# Use CIS Reference:                        False
#
#
# Use exact evolutoin:                      False
#
#
# Expansion type:                           GSD
# Use DIIS:                                 False
# Max DIIS size:                            False
# Use selected pool:                        False
# x value threshold:                        1e-10
# Use sparse tensors to solve Sx = b:       False
#
#
# Use low memory mode:                      True
# Use 2nd order derivation of QITE:         True
# Do Quantum Lanczos                        False
#
#
#
#
# ==> Building expansion pool <==
#    beta           E(beta)     N(params)           N(CNOT)          N(measure)
# -------------------------------------------------------------------------------
#    0.000       -3.156000929           0                 0                   0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 GSD_path = run_qite(
#       2     mol,
#       3     beta=2.0,
#       4     db=0.1,
#       5     expansion_type='GSD',
#       6     low_memorySb=True,
#       7     second_order=True,
#       8     output_path=cnot_path)
#      10 # b_GSD = [float(item) for item in h6_GSD_beta]
#      11 # e_GSD = [abs(float(item) - mol.fci_energy) for item in h6_GSD_energy]
#      12 # p_GSD = [int(item) for item in h6_GSD_param]
#      13 # c_GSD  = [int(item) for item in h6_GSD_cnot]
#      14 # m_GSD = [int(item) for item in h6_GSD_measure]
#
# File ~/Desktop/rsrch/2025_sqite/run_job.py:67, in run_qite(sys, computer_type, apply_ham_as_tensor, ref, state_prep_type, trotter_order, trotter_number, fast, verbose, print_summary_file, beta, db, dt, use_diis, max_diis_size, use_exact_evolution, expansion_type, evolve_dfham, random_state, sparseSb, low_memorySb, second_order, selected_pool, t_thresh, cumulative_t, b_thresh, x_thresh, conv_thresh, physical_r, folded_spectrum, BeH2_guess, e_shift, update_e_shift, do_lanczos, lanczos_gap, realistic_lanczos, fname, output_path, print_pool, use_cis_reference, target_root, cis_target_root, new)
#      55 if(new):
#      56     alg = QITE(system=sys,
#      57             computer_type=computer_type,
#      58             apply_ham_as_tensor=apply_ham_as_tensor,
#    (...)
#      64             verbose=verbose,
#      65             print_summary_file=print_summary_file)
# ---> 67     alg.run(beta=beta,
#      68             db=db,
#      69             dt=dt,
#      70             use_diis=use_diis,
#      71             max_diis_size=max_diis_size,
#      72             use_exact_evolution=use_exact_evolution,
#      73             expansion_type=expansion_type,
#      74             evolve_dfham=evolve_dfham,
#      75             random_state=random_state,
#      76             sparseSb=sparseSb,
#      77             low_memorySb=low_memorySb,
#      78             second_order=second_order,
#      79             selected_pool=selected_pool,
#      80             t_thresh=t_thresh,
#      81             cumulative_t=cumulative_t,
#      82             b_thresh=b_thresh,
#      83             x_thresh=x_thresh,
#      84             conv_thresh=conv_thresh,
#      85             physical_r=physical_r,
#      86             folded_spectrum=folded_spectrum,
#      87             BeH2_guess=BeH2_guess,
#      88             e_shift=e_shift,
#      89             update_e_shift=update_e_shift,
#      90             do_lanczos=do_lanczos,
#      91             lanczos_gap=lanczos_gap,
#      92             realistic_lanczos=realistic_lanczos,
#      93             fname=fname,
#      94             output_path=output_path,
#      95             print_pool=print_pool,
#      96             use_cis_reference=use_cis_reference,
#      97             target_root=target_root,
#      98             cis_target_root=cis_target_root)
#     100     if(use_exact_evolution):
#     101         path = f'{output_path}qite_beta_{beta}_db_{db}_EXACT_EVOLUTION_summary.dat'
#
# File ~/Desktop/rsrch/qforte/src/qforte/ite/qite.py:390, in QITE.run(self, beta, db, dt, use_diis, max_diis_size, use_exact_evolution, expansion_type, evolve_dfham, random_state, sparseSb, low_memorySb, second_order, selected_pool, t_thresh, cumulative_t, b_thresh, x_thresh, conv_thresh, physical_r, folded_spectrum, BeH2_guess, e_shift, update_e_shift, do_lanczos, lanczos_gap, realistic_lanczos, fname, output_path, print_pool, use_cis_reference, target_root, cis_target_root)
#     387 timer = qf.local_timer()
#     388 timer.reset()
# --> 390 self.evolve()
#     392 timer.record('Total evolution time')
#     393 print(f"\n\n{timer}\n\n")
#
# File ~/Desktop/rsrch/qforte/src/qforte/ite/qite.py:1310, in QITE.evolve(self)
#    1297     self._NI = len(self._sig.terms())
#    1299     #do CNOT estimation here
#    1300     # n_res_m = 1
#    1301     # self._n_cnot += (n_res_m*total_pool_cnot + qite_cnot)
#    (...)
#    1307
#    1308 # self._n_cnot += qite_cnot
# -> 1310 self.do_qite_step()
#    1312 if(self._do_lanczos):
#    1313     if(self._realistic_lanczos):
#
# File ~/Desktop/rsrch/qforte/src/qforte/ite/qite.py:800, in QITE.do_qite_step(self)
#     797         print(f"Warning, build sparseSb method isn't supported for FCI computer, setting option to false")
#     798         self._sparseSb = False
# --> 800     S, btot = self.build_S_b_FCI()
#     802 if(self._computer_type=='fock'):
#     803     if(self._low_memorySb):
#
# File ~/Desktop/rsrch/qforte/src/qforte/ite/qite.py:673, in QITE.build_S_b_FCI(self)
#     671 for j in range(i):
#     672     Ipsi_qc.set_state(self._qc.get_state_deep())
# --> 673     Ipsi_qc.apply_sqop(self._sig.terms()[j][1])
#     675     S[i][j] = Ipsi_mu.vector_dot(Ipsi_qc.get_state_deep())
#     676     S[j][i] = S[i][j].conj()
#
# KeyboardInterrupt:

# %%
h6_kUpCCGSD_beta, h6_kUpCCGSD_energy, h6_kUpCCGSD_param, h6_kUpCCGSD_cnot, h6_kUpCCGSD_measure = run_qite(
    mol,
    beta=10.0,
    db=0.1,
    expansion_type='2-UpCCGSD',
    second_order=True,
    output_path=cnot_path)

b_kUp = [float(item) for item in h6_kUpCCGSD_beta]
e_kUp = [abs(float(item) - mol.fci_energy) for item in h6_kUpCCGSD_energy]
p_kUp = [int(item) for item in h6_kUpCCGSD_param]
c_kUp  = [int(item) for item in h6_kUpCCGSD_cnot]
m_kUp = [int(item) for item in h6_kUpCCGSD_measure]
# Out:
# -----------------------------------------------------
#      Quantum Imaginary Time Evolution Algorithm
# -----------------------------------------------------
#
#
#                  ==> QITE options <==
# -----------------------------------------------------------
# Computer Type:                            fci
# Trial reference state:                    |111111000000>
# Number of Hamiltonian Pauli terms:        919
# Trial state preparation method:           occupation_list
# Trotter order (rho):                      1
# Trotter number (m):                       1
# Use fast version of algorithm:            True
#
#
# Total imaginary evolution time (beta):    10.0
# Imaginary time step (db):                 0.1
#
#
# Use Folded Spectrum:                      False
#
#
# Use CIS Reference:                        False
#
#
# Use exact evolutoin:                      False
#
#
# Expansion type:                           2-UpCCGSD
# Use DIIS:                                 False
# Max DIIS size:                            False
# Use selected pool:                        False
# x value threshold:                        1e-10
# Use sparse tensors to solve Sx = b:       False
#
#
# Use low memory mode:                      False
# Use 2nd order derivation of QITE:         True
# Do Quantum Lanczos                        False
#
#
#
#
# ==> Building expansion pool <==
#    beta           E(beta)     N(params)           N(CNOT)          N(measure)
# -------------------------------------------------------------------------------
#    0.000       -3.156000929           0                 0                   0
#    0.100       -3.166288902          90               900              468915
#    0.200       -3.173017041         180              1800              937830
#    0.300       -3.177566500         270              2700             1406745
#    0.400       -3.180743396         360              3600             1875660
#    0.500       -3.183029476         450              4500             2344575
#    0.600       -3.184720320         540              5400             2813490
#    0.700       -3.186002315         630              6300             3282405
#    0.800       -3.186996225         720              7200             3751320
#    0.900       -3.187782360         810              8100             4220235
#    1.000       -3.188415439         900              9000             4689150
#    1.100       -3.188933579         990              9900             5158065
#    1.200       -3.189363874        1080             10800             5626980
#    1.300       -3.189725937        1170             11700             6095895
#    1.400       -3.190034197        1260             12600             6564810
#    1.500       -3.190299433        1350             13500             7033725
#    1.600       -3.190529809        1440             14400             7502640
#    1.700       -3.190731592        1530             15300             7971555
#    1.800       -3.190909646        1620             16200             8440470
#    1.900       -3.191067799        1710             17100             8909385
#    2.000       -3.191209092        1800             18000             9378300
#    2.100       -3.191335969        1890             18900             9847215
#    2.200       -3.191450415        1980             19800            10316130
#    2.300       -3.191554060        2070             20700            10785045
#    2.400       -3.191648254        2160             21600            11253960
#    2.500       -3.191734126        2250             22500            11722875
#    2.600       -3.191812627        2340             23400            12191790
#    2.700       -3.191884568        2430             24300            12660705
#    2.800       -3.191950643        2520             25200            13129620
#    2.900       -3.192011452        2610             26100            13598535
#    3.000       -3.192067517        2700             27000            14067450
#    3.100       -3.192119292        2790             27900            14536365
#    3.200       -3.192167179        2880             28800            15005280
#    3.300       -3.192211532        2970             29700            15474195
#    3.400       -3.192252665        3060             30600            15943110
#    3.500       -3.192290860        3150             31500            16412025
#    3.600       -3.192326367        3240             32400            16880940
#    3.700       -3.192359411        3330             33300            17349855
#    3.800       -3.192390197        3420             34200            17818770
#    3.900       -3.192418907        3510             35100            18287685
#    4.000       -3.192445708        3600             36000            18756600
#    4.100       -3.192470750        3690             36900            19225515
#    4.200       -3.192494172        3780             37800            19694430
#    4.300       -3.192516098        3870             38700            20163345
#    4.400       -3.192536643        3960             39600            20632260
#    4.500       -3.192555912        4050             40500            21101175
#    4.600       -3.192574000        4140             41400            21570090
#    4.700       -3.192590995        4230             42300            22039005
#    4.800       -3.192606978        4320             43200            22507920
#    4.900       -3.192622023        4410             44100            22976835
#    5.000       -3.192636198        4500             45000            23445750
    physical_r = True,
    output_path=cnot_path)

# b_t1 = [float(item) for item in h6_t1_beta]
# e_t1 = [abs(float(item) - mol.fci_energy) for item in h6_t1_energy]
# p_t1 = [int(item) for item in h6_t1_param]
# c_t1  = [int(item) for item in h6_t1_cnot]
# m_t1 = [int(item) for item in h6_t1_measure]
# Out:
# -----------------------------------------------------
#      Quantum Imaginary Time Evolution Algorithm
# -----------------------------------------------------
#
#
#                  ==> QITE options <==
# -----------------------------------------------------------
# Computer Type:                            fci
# Trial reference state:                    |111111000000>
# Number of Hamiltonian Pauli terms:        919
# Trial state preparation method:           occupation_list
# Trotter order (rho):                      1
# Trotter number (m):                       1
# Use fast version of algorithm:            True
#
#
# Total imaginary evolution time (beta):    11.1
# Imaginary time step (db):                 0.1
#
#
# Use Folded Spectrum:                      False
#
#
# Use CIS Reference:                        False
#
#
# Use exact evolutoin:                      False
#
#
# Expansion type:                           All
# Use DIIS:                                 False
# Max DIIS size:                            False
# Use selected pool:                        True
# Use cumulative selection:                 True
# Use physical selection:                   True
# Selection time step (dt):                 0.01
# x value threshold:                        1e-10
# Use sparse tensors to solve Sx = b:       False
#
#
# Use low memory mode:                      False
# Use 2nd order derivation of QITE:         True
# Do Quantum Lanczos                        False
#
#
#
#
# ==> Building expansion pool <==
#    beta           E(beta)     N(params)           N(CNOT)          N(measure)
# -------------------------------------------------------------------------------
#    0.000       -3.156000929           0                 0                   0
#    0.100       -3.161032396           3              6818               13764
#    0.200       -3.165535558           6              6900               27528
#    0.300       -3.168620608           8              6980               37627
#    0.400       -3.171294700          10              7048               47726
#    0.500       -3.173829963          12              7128               57825
#    0.600       -3.176273562          14              7192               67924
#    0.700       -3.177479647          15              7238               74614
#    0.800       -3.178627047          16              7272               81304
#    0.900       -3.179610845          17              7298               87994
#    1.000       -3.180615272          18              7336               94684
#    1.100       -3.181646523          19              7362              101374
#    1.200       -3.182665170          20              7388              108064
#    1.300       -3.183595958          21              7438              114754
#    1.400       -3.183595958          21              7482              118099
#    1.500       -3.183595958          21              7482              121444
#    1.600       -3.183595958          21              7482              124789
#    1.700       -3.183595958          21              7482              128134
#    1.800       -3.183595958          21              7482              131479
#    1.900       -3.183595958          21              7482              134824
#    2.000       -3.183595958          21              7482              138169
#    2.100       -3.183595958          21              7482              141514
#    2.200       -3.183595958          21              7482              144859
#    2.300       -3.183595958          21              7482              148204
#    2.400       -3.183595958          21              7482              151549
#    2.500       -3.183595958          21              7482              154894
#    2.600       -3.183595958          21              7482              158239
#    2.700       -3.183595958          21              7482              161584
#    2.800       -3.183595958          21              7482              164929
#    2.900       -3.183595958          21              7482              168274
#    3.000       -3.183595958          21              7482              171619
#    3.100       -3.183595958          21              7482              174964
#    3.200       -3.183595958          21              7482              178309
#    3.300       -3.183595958          21              7482              181654
#    3.400       -3.183595958          21              7482              184999
#    3.500       -3.183595958          21              7482              188344
#    3.600       -3.183595958          21              7482              191689
#    3.700       -3.183595958          21              7482              195034
#   10.800       -3.183595958          21              7482              432529
#   10.900       -3.183595958          21              7482              435874
#   11.000       -3.183595958          21              7482              439219
#
#
#         Process name            Time (s)             Percent
#        =============       =============       =============
# Total evolution time              2.0105              100.00
#
#           Total Time              2.0105              100.00
#
#
#
#
#
#     Process name        Time (s)         Percent
#    =============   =============   =============
#    c++ selection          0.0003           99.82
# python selection          0.0000            0.18
#
#       Total Time          0.0003          100.00
#
#
#
#
#
#                         ==> QITE summary <==
# -----------------------------------------------------------
# Final QITE Energy:                         -3.183595958
# Number of operators in pool:               0
# Number of classical parameters used:       21
# Estimated classical memory usage (GB):     2.553600e-03
# Number of CNOT gates in deepest circuit:   7482
# Number of Pauli term measurements:         439219

# %%
wot_p = run_qite(
    mol,
    beta=11.1,
    db=0.1,
    expansion_type='All',
    second_order=True,
    selected_pool=True,
    t_thresh=theta_2,
    physical_r = True,
    output_path=cnot_path)

# b_t2 = [float(item) for item in h6_t2_beta]
# e_t2 = [abs(float(item) - mol.fci_energy) for item in h6_t2_energy]
# p_t2 = [int(item) for item in h6_t2_param]
# c_t2  = [int(item) for item in h6_t2_cnot]
# m_t2 = [int(item) for item in h6_t2_measure]
# Out:
# -----------------------------------------------------
#      Quantum Imaginary Time Evolution Algorithm
# -----------------------------------------------------
#
#
#                  ==> QITE options <==
# -----------------------------------------------------------
# Computer Type:                            fci
# Trial reference state:                    |111111000000>
# Number of Hamiltonian Pauli terms:        919
# Trial state preparation method:           occupation_list
# Trotter order (rho):                      1
# Trotter number (m):                       1
# Use fast version of algorithm:            True
#
#
# Total imaginary evolution time (beta):    11.1
# Imaginary time step (db):                 0.1
#
#
# Use Folded Spectrum:                      False
#
#
# Use CIS Reference:                        False
#
#
# Use exact evolutoin:                      False
#
#
# Expansion type:                           All
# Use DIIS:                                 False
# Max DIIS size:                            False
# Use selected pool:                        True
# Use cumulative selection:                 True
# Use physical selection:                   True
# Selection time step (dt):                 0.01
# x value threshold:                        1e-10
# Use sparse tensors to solve Sx = b:       False
#
#
# Use low memory mode:                      False
# Use 2nd order derivation of QITE:         True
# Do Quantum Lanczos                        False
#
#
#
#
# ==> Building expansion pool <==
#    beta           E(beta)     N(params)           N(CNOT)          N(measure)
# -------------------------------------------------------------------------------
#    0.000       -3.156000929           0                 0                   0
#    0.100       -3.176951034          31              7296              166112
#    0.200       -3.192589761          62              8800              332224
#    0.300       -3.204294560          91             10248              483326
#    0.400       -3.213253158         119             11598              628523
#    0.500       -3.220179277         145             12872              758646
#    0.600       -3.225647496         169             14036              877343
#    0.700       -3.229982246         191             15118              982758
#    0.800       -3.233413387         210             16088             1070810
#    0.900       -3.236227151         228             16924             1153885
#    1.000       -3.238509841         244             17716             1225182
#    1.100       -3.240365377         258             18388             1286077
#    1.200       -3.241888505         270             18986             1337882
#    1.300       -3.243154615         280             19500             1380245
#    1.400       -3.244174960         288             19922             1414254
#    1.500       -3.245051355         295             20268             1443958
#    8.400       -3.250065495         345             22398             1848733
#    8.500       -3.250065495         345             22398             1852078
#    8.600       -3.250065495         345             22398             1855423
#    8.700       -3.250065495         345             22398             1858768
#    8.800       -3.250065495         345             22398             1862113
#    8.900       -3.250065495         345             22398             1865458
#    9.000       -3.250065495         345             22398             1868803
#    9.100       -3.250065495         345             22398             1872148
#    9.200       -3.250065495         345             22398             1875493
#    9.300       -3.250065495         345             22398             1878838
#    9.400       -3.250065495         345             22398             1882183
#    9.500       -3.250065495         345             22398             1885528
#    9.600       -3.250065495         345             22398             1888873
#    9.700       -3.250065495         345             22398             1892218
#    9.800       -3.250065495         345             22398             1895563
#    9.900       -3.250065495         345             22398             1898908
#   10.000       -3.250065495         345             22398             1902253
#   10.100       -3.250065495         345             22398             1905598
#   10.200       -3.250065495         345             22398             1908943
#   10.300       -3.250065495         345             22398             1912288
#   10.400       -3.250065495         345             22398             1915633
#   10.500       -3.250065495         345             22398             1918978
#   10.600       -3.250065495         345             22398             1922323
#   10.700       -3.250065495         345             22398             1925668
#   10.800       -3.250065495         345             22398             1929013
#   10.900       -3.250065495         345             22398             1932358
#   11.000       -3.250065495         345             22398             1935703
#
#
#         Process name            Time (s)             Percent
#        =============       =============       =============
# Total evolution time              2.2426              100.00
#
#           Total Time              2.2426              100.00
#
#
#
#
#
#     Process name        Time (s)         Percent
#    =============   =============   =============
#    c++ selection          0.0004           99.57
# python selection          0.0000            0.43
#
#       Total Time          0.0004          100.00
#
#
#
#
#
#                         ==> QITE summary <==
# -----------------------------------------------------------
# Final QITE Energy:                         -3.2500654948
# Number of operators in pool:               0
# Number of classical parameters used:       345
# Estimated classical memory usage (GB):     2.553600e-03
# Number of CNOT gates in deepest circuit:   22398
# Number of Pauli term measurements:         1935703

# %%
wotever_path = run_qite(
    mol,
    beta=11.1,
    db=0.1,
    expansion_type='All',
    second_order=True,
    selected_pool=True,
    t_thresh=theta_3,
    conv_thresh=1.0e-3,
    physical_r = True,
    output_path=cnot_path)

# b_t3 = [float(item) for item in h6_t3_beta]
# e_t3 = [abs(float(item) - mol.fci_energy) for item in h6_t3_energy]
# p_t3 = [int(item) for item in h6_t3_param]
# c_t3  = [int(item) for item in h6_t3_cnot]
# m_t3 = [int(item) for item in h6_t3_measure]
# Out:
# -----------------------------------------------------
#      Quantum Imaginary Time Evolution Algorithm
# -----------------------------------------------------
#
#
#                  ==> QITE options <==
# -----------------------------------------------------------
# Computer Type:                            fci
# Trial reference state:                    |111111000000>
# Number of Hamiltonian Pauli terms:        919
# Trial state preparation method:           occupation_list
# Trotter order (rho):                      1
# Trotter number (m):                       1
# Use fast version of algorithm:            True
#
#
# Total imaginary evolution time (beta):    11.1
# Imaginary time step (db):                 0.1
#
#
# Use Folded Spectrum:                      False
#
#
# Use CIS Reference:                        False
#
#
# Use exact evolutoin:                      False
#
#
# Expansion type:                           All
# Use DIIS:                                 False
# Max DIIS size:                            False
# Use selected pool:                        True
# Use cumulative selection:                 True
# Use physical selection:                   True
# Selection time step (dt):                 0.01
# x value threshold:                        1e-10
# Use sparse tensors to solve Sx = b:       False
#
#
# Use low memory mode:                      False
# Use 2nd order derivation of QITE:         True
# Do Quantum Lanczos                        False
#
#
#
#
# ==> Building expansion pool <==
#    beta           E(beta)     N(params)           N(CNOT)          N(measure)
# -------------------------------------------------------------------------------
#    0.000       -3.156000929           0                 0                   0
#    0.100       -3.178589706          45              7534              276494
#    0.200       -3.195304241          90              9760              552988
#    0.300       -3.207870651         136             12006              838011
#    0.400       -3.217387062         181             14276             1114089
#    0.500       -3.224702413         225             16492             1380838
#    0.600       -3.230413186         269             18668             1648995
#    0.700       -3.234918236         312             20800             1907215
#    0.800       -3.238513674         354             22836             2157866
#    0.900       -3.241418343         396             24886             2408549
#    1.000       -3.243782156         437             26906             2649487
#    1.100       -3.245721531         478             28880             2891513
#    1.200       -3.247328190         518             30858             3150770
#    1.300       -3.248665267         556             32758             3400457
#    1.400       -3.249786763         592             34514             3617854
#    1.500       -3.250730836         626             36192             3843505
#    1.600       -3.251531768         657             37762             4069681
#    1.700       -3.252211471         684             39186             4226989
#    1.800       -3.252795247         709             40426             4371047
#    1.900       -3.253296586         731             41564             4489198
#    2.000       -3.253727821         750             42532             4599618
#    2.100       -3.254101137         767             43386             4679444
#    2.200       -3.254427111         783             44182             4762709
#    2.300       -3.254707519         797             44894             4830356
#    2.400       -3.254952373         810             45488             4901890
#    2.500       -3.255168299         822             46052             4955999
#    2.600       -3.255357439         833             46558             5004331
#    2.700       -3.255526252         844             47026             5053175
#    2.800       -3.255672349         854             47486             5100274
#    2.900       -3.255800967         863             47908             5139612
#    3.000       -3.255915563         872             48320             5181126
#    3.100       -3.256015160         880             48694             5214815
#    3.200       -3.256103170         887             49030             5245927
#    3.300       -3.256181601         894             49322             5275887
#    3.400       -3.256251470         901             49610             5305399
#    3.500       -3.256314595         908             49914             5339455
#    3.600       -3.256369354         914             50198             5365110
#    3.700       -3.256416400         919             50436             5386204
#    3.800       -3.256460966         925             50630             5412019
#    3.900       -3.256499390         930             50874             5434521
#    4.000       -3.256534136         935             51090             5456127
#    4.100       -3.256565797         940             51306             5477989
#    4.200       -3.256593190         945             51500             5498587
#    4.300       -3.256619218         950             51658             5520705
# qite converged for convergence threshold 0.001 Hartree
#
#
#         Process name            Time (s)             Percent
#        =============       =============       =============
# Total evolution time              1.7300              100.00
#
#           Total Time              1.7300              100.00
#
#
#
#
#
#     Process name        Time (s)         Percent
#    =============   =============   =============
#    c++ selection          0.0008           99.94
# python selection          0.0000            0.06
#
#       Total Time          0.0008          100.00
#
#
#
#
#
#                         ==> QITE summary <==
# -----------------------------------------------------------
# Final QITE Energy:                         -3.2566192185
# Number of operators in pool:               5
# Number of classical parameters used:       950
# Estimated classical memory usage (GB):     2.553600e-03
# Number of CNOT gates in deepest circuit:   51658
# Number of Pauli term measurements:         5520705
