# %%
import numpy as np
import qforte as qf
import matplotlib.pyplot as plt

from run_job import run_qite

from geometries.chain_geom import get_h10chain_geom as chain
from geometries.pyramid_geom import get_h10pyr_geom as pyrmd
from geometries.ring_geom import get_h10ring_geom as ring
from geometries.sheet_geom import get_h10sheet_geom as sheet

# %%
c_path_1 = '/home/victorlucalita/src/my_qforte/2025_sqite/h10/ang_10/chain/'
r_path_1 = '/home/victorlucalita/src/my_qforte/2025_sqite/h10/ang_10/ring/'
s_path_1 = '/home/victorlucalita/src/my_qforte/2025_sqite/h10/ang_10/sheet/'
p_path_1 = '/home/victorlucalita/src/my_qforte/2025_sqite/h10/ang_10/pyramid/'

c_path_15 = '/home/victorlucalita/src/my_qforte/2025_sqite/h10/ang_15/chain/'
r_path_15 = '/home/victorlucalita/src/my_qforte/2025_sqite/h10/ang_15/ring/'
s_path_15 = '/home/victorlucalita/src/my_qforte/2025_sqite/h10/ang_15/sheet/'
p_path_15 = '/home/victorlucalita/src/my_qforte/2025_sqite/h10/ang_15/pyramid/'

# %%
theta_1 = 1.0e-5
theta_2 = 1.0e-6
theta_3 = 1.0e-7

# %%
chain_mol_1 = qf.system_factory(build_type='psi4', mol_geometry=chain(1.0), basis='sto-6g', run_fci=True)
print(f'The FCI energy from Psi4:                                    {chain_mol_1.fci_energy:12.10f}')
print(f'The HF energy from Psi4:                                     {chain_mol_1.hf_energy:12.10f}')

ring_mol_1 = qf.system_factory(build_type='psi4', mol_geometry=ring(1.0), basis='sto-6g', run_fci=True)
print(f'The FCI energy from Psi4:                                    {ring_mol_1.fci_energy:12.10f}')
print(f'The HF energy from Psi4:                                     {ring_mol_1.hf_energy:12.10f}')

sheet_mol_1 = qf.system_factory(build_type='psi4', mol_geometry=sheet(1.0), basis='sto-6g', run_fci=True)
print(f'The FCI energy from Psi4:                                    {sheet_mol_1.fci_energy:12.10f}')
print(f'The HF energy from Psi4:                                     {sheet_mol_1.hf_energy:12.10f}')

pyrmd_mol_1 = qf.system_factory(build_type='psi4', mol_geometry=pyrmd(1.0), basis='sto-6g', run_fci=True)
print(f'The FCI energy from Psi4:                                    {pyrmd_mol_1.fci_energy:12.10f}')
print(f'The HF energy from Psi4:                                     {pyrmd_mol_1.hf_energy:12.10f}')

chain_mol_15 = qf.system_factory(build_type='psi4', mol_geometry=chain(1.5), basis='sto-6g', run_fci=True)
print(f'The FCI energy from Psi4:                                    {chain_mol_15.fci_energy:12.10f}')
print(f'The HF energy from Psi4:                                     {chain_mol_15.hf_energy:12.10f}')

ring_mol_15 = qf.system_factory(build_type='psi4', mol_geometry=ring(1.5), basis='sto-6g', run_fci=True)
print(f'The FCI energy from Psi4:                                    {ring_mol_15.fci_energy:12.10f}')
print(f'The HF energy from Psi4:                                     {ring_mol_15.hf_energy:12.10f}')

sheet_mol_15 = qf.system_factory(build_type='psi4', mol_geometry=sheet(1.5), basis='sto-6g', run_fci=True)
print(f'The FCI energy from Psi4:                                    {sheet_mol_15.fci_energy:12.10f}')
print(f'The HF energy from Psi4:                                     {sheet_mol_15.hf_energy:12.10f}')

pyrmd_mol_15 = qf.system_factory(build_type='psi4', mol_geometry=pyrmd(1.5), basis='sto-6g', run_fci=True)
print(f'The FCI energy from Psi4:                                    {pyrmd_mol_15.fci_energy:12.10f}')
print(f'The HF energy from Psi4:                                     {pyrmd_mol_15.hf_energy:12.10f}')
# Out:
#  ==> Psi4 geometry <==
# -------------------------
# 0  1
# H  0.0  0.0  4.5
# H  0.0  0.0  3.5
# H  0.0  0.0  2.5
# H  0.0  0.0  1.5
# H  0.0  0.0  0.5
# H  0.0  0.0  -0.5
# H  0.0  0.0  -1.5
# H  0.0  0.0  -2.5
# H  0.0  0.0  -3.5
# H  0.0  0.0  -4.5
# symmetry c1
# units angstrom
#
#   Memory set to   1.863 GiB by Python driver.
# The FCI energy from Psi4:                                    -5.4153933166
# The HF energy from Psi4:                                     -5.2476173423
#  ==> Psi4 geometry <==
# -------------------------
# 0  1
# H  1.618033988749895  0.0  0.0
# H  1.3090169943749475  0.9510565162951536  0.0
# H  0.5000000000000001  1.5388417685876268  0.0
# H  -0.4999999999999999  1.5388417685876268  0.0
# H  -1.3090169943749472  0.9510565162951538  0.0
# H  -1.618033988749895  1.9815201452341832e-16  0.0
# H  -1.3090169943749477  -0.9510565162951534  0.0
# H  -0.5000000000000002  -1.5388417685876268  0.0
# H  0.4999999999999997  -1.5388417685876268  0.0
# H  1.3090169943749472  -0.951056516295154  0.0
# symmetry c1
# units angstrom
# The FCI energy from Psi4:                                    -5.4229584331
# The HF energy from Psi4:                                     -5.2754518521
#  ==> Psi4 geometry <==
# -------------------------
# 0  1
# H  -1.0  0.8660254037844387  0.0
# H  0.0  0.8660254037844387  0.0
# H  1.0  0.8660254037844387  0.0
# H  -1.5  0.0  0.0
# H  -0.5  0.0  0.0
# H  0.5  0.0  0.0
# H  1.5  0.0  0.0
# H  -1.0  -0.8660254037844387  0.0
# H  0.0  -0.8660254037844387  0.0
# H  1.0  -0.8660254037844387  0.0
# symmetry c1
# units angstrom
# The FCI energy from Psi4:                                    -4.8915377195
# The HF energy from Psi4:                                     -4.7522787032
#  ==> Psi4 geometry <==
# -------------------------
# 0  1
# H  0.0  1.1547005383792515  -0.816496580927726
# H  -0.5  0.28867513459481287  -0.816496580927726
# H  0.5  0.28867513459481287  -0.816496580927726
# H  -1.0  -0.5773502691896257  -0.816496580927726
# H  0.0  -0.5773502691896257  -0.816496580927726
# H  1.0  -0.5773502691896257  -0.816496580927726
# H  0.0  0.5773502691896257  0.0
# H  -0.5  -0.28867513459481287  0.0
# H  0.5  -0.28867513459481287  0.0
# H  0.0  0.0  0.816496580927726
# symmetry c1
# units angstrom
# The FCI energy from Psi4:                                    -4.2693786412
# The HF energy from Psi4:                                     -4.0296403959
#  ==> Psi4 geometry <==
# -------------------------
# 0  1
# H  0.0  0.0  6.75
# H  0.0  0.0  5.25
# H  0.0  0.0  3.75
# H  0.0  0.0  2.25
# H  0.0  0.0  0.75
# H  0.0  0.0  -0.75
# H  0.0  0.0  -2.25
# H  0.0  0.0  -3.75
# H  0.0  0.0  -5.25
# H  0.0  0.0  -6.75
# symmetry c1
# units angstrom
# The FCI energy from Psi4:                                    -5.0362929897
# The HF energy from Psi4:                                     -4.6324858327
#  ==> Psi4 geometry <==
# -------------------------
# 0  1
# H  2.4270509831248424  0.0  0.0
# H  1.9635254915624212  1.4265847744427305  0.0
# H  0.7500000000000001  2.30826265288144  0.0
# H  -0.7499999999999998  2.3082626528814405  0.0
# H  -1.963525491562421  1.4265847744427307  0.0
# H  -2.4270509831248424  2.972280217851275e-16  0.0
# H  -1.9635254915624216  -1.4265847744427302  0.0
# H  -0.7500000000000003  -2.30826265288144  0.0
# H  0.7499999999999996  -2.3082626528814405  0.0
# H  1.963525491562421  -1.426584774442731  0.0
# symmetry c1
# units angstrom
# The FCI energy from Psi4:                                    -5.0480518541
# The HF energy from Psi4:                                     -4.6864624999
#  ==> Psi4 geometry <==
# -------------------------
# 0  1
# H  -1.5  1.299038105676658  0.0
# H  0.0  1.299038105676658  0.0
# H  1.5  1.299038105676658  0.0
# H  -2.25  0.0  0.0
# H  -0.75  0.0  0.0
# H  0.75  0.0  0.0
# H  2.25  0.0  0.0
# H  -1.5  -1.299038105676658  0.0
# H  0.0  -1.299038105676658  0.0
# H  1.5  -1.299038105676658  0.0
# symmetry c1
# units angstrom
# The FCI energy from Psi4:                                    -4.9031924720
# The HF energy from Psi4:                                     -4.6163768203
#  ==> Psi4 geometry <==
# -------------------------
# 0  1
# H  0.0  1.7320508075688772  -1.224744871391589
# H  -0.75  0.4330127018922193  -1.224744871391589
# H  0.75  0.4330127018922193  -1.224744871391589
# H  -1.5  -0.8660254037844386  -1.224744871391589
# H  0.0  -0.8660254037844386  -1.224744871391589
# H  1.5  -0.8660254037844386  -1.224744871391589
# H  0.0  0.8660254037844386  0.0
# H  -0.75  -0.4330127018922193  0.0
# H  0.75  -0.4330127018922193  0.0
# H  0.0  0.0  1.224744871391589
# symmetry c1
# units angstrom
# The FCI energy from Psi4:                                    -4.7334586087
# The HF energy from Psi4:                                     -4.3283101051

# %%
chain_path_1_t1 = run_qite(
    chain_mol_1,
    beta=0.0,
    db=0.1,
    expansion_type='All',
    second_order=True,
    selected_pool=True,
    t_thresh=theta_1,
    conv_thresh=1.0e-4,
    physical_r = True,
    output_path=c_path_1)
# Out:
# -----------------------------------------------------
#      Quantum Imaginary Time Evolution Algorithm
# -----------------------------------------------------
#
#
#                  ==> QITE options <==
# -----------------------------------------------------------
# Computer Type:                            fci
# Trial reference state:                    |11111111110000000000>
# Number of Hamiltonian Pauli terms:        7151
# Trial state preparation method:           occupation_list
# Trotter order (rho):                      1
# Trotter number (m):                       1
# Use fast version of algorithm:            True
#
#
# Total imaginary evolution time (beta):    0.0
# Imaginary time step (db):                 0.1
#
#
# Use Folded Spectrum:                      False
#
#
# Use CIS Reference:                        False
#
#
# Use exact evolutoin:                      False
#
#
# Expansion type:                           All
# Use DIIS:                                 False
# Max DIIS size:                            False
# Use selected pool:                        True
# Use cumulative selection:                 True
# Use physical selection:                   True
# Selection time step (dt):                 0.01
# x value threshold:                        1e-10
# Use sparse tensors to solve Sx = b:       False
#
#
# Use low memory mode:                      False
# Use 2nd order derivation of QITE:         True
# Do Quantum Lanczos                        False
#
#
#
#
# ==> Building expansion pool <==
#
#
# WARNING: ESTIMATED MEMORY USAGE EXCEEDS 8GB, SWITCHING TO LOW MEMORY MODE
#
#
#    beta           E(beta)     N(params)           N(CNOT)          N(measure)
# -------------------------------------------------------------------------------
#    0.000       -5.247617342           0                 0                   0
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 chain_path_1_t1 = run_qite(
#       2     chain_mol_1,
#       3     beta=0.0,
#       4     db=0.1,
#       5     expansion_type='All',
#       6     second_order=True,
#       7     selected_pool=True,
#       8     t_thresh=theta_1,
#       9     conv_thresh=1.0e-4,
#      10     physical_r = True,
#      11     output_path=c_path_1)
#
# File ~/Desktop/rsrch/2025_sqite/run_job.py:67, in run_qite(sys, computer_type, apply_ham_as_tensor, ref, state_prep_type, trotter_order, trotter_number, fast, verbose, print_summary_file, beta, db, dt, use_diis, max_diis_size, use_exact_evolution, expansion_type, evolve_dfham, random_state, sparseSb, low_memorySb, second_order, selected_pool, t_thresh, cumulative_t, b_thresh, x_thresh, conv_thresh, physical_r, folded_spectrum, BeH2_guess, e_shift, update_e_shift, do_lanczos, lanczos_gap, realistic_lanczos, fname, output_path, print_pool, use_cis_reference, target_root, cis_target_root, new)
#      55 if(new):
#      56     alg = QITE(system=sys,
#      57             computer_type=computer_type,
#      58             apply_ham_as_tensor=apply_ham_as_tensor,
#    (...)
#      64             verbose=verbose,
#      65             print_summary_file=print_summary_file)
# ---> 67     alg.run(beta=beta,
#      68             db=db,
#      69             dt=dt,
#      70             use_diis=use_diis,
#      71             max_diis_size=max_diis_size,
#      72             use_exact_evolution=use_exact_evolution,
#      73             expansion_type=expansion_type,
#      74             evolve_dfham=evolve_dfham,
#      75             random_state=random_state,
#      76             sparseSb=sparseSb,
#      77             low_memorySb=low_memorySb,
#      78             second_order=second_order,
#      79             selected_pool=selected_pool,
#      80             t_thresh=t_thresh,
#      81             cumulative_t=cumulative_t,
#      82             b_thresh=b_thresh,
#      83             x_thresh=x_thresh,
#      84             conv_thresh=conv_thresh,
#      85             physical_r=physical_r,
#      86             folded_spectrum=folded_spectrum,
#      87             BeH2_guess=BeH2_guess,
#      88             e_shift=e_shift,
#      89             update_e_shift=update_e_shift,
#      90             do_lanczos=do_lanczos,
#      91             lanczos_gap=lanczos_gap,
#      92             realistic_lanczos=realistic_lanczos,
#      93             fname=fname,
#      94             output_path=output_path,
#      95             print_pool=print_pool,
#      96             use_cis_reference=use_cis_reference,
#      97             target_root=target_root,
#      98             cis_target_root=cis_target_root)
#     100     if(use_exact_evolution):
#     101         path = f'{output_path}qite_beta_{beta}_db_{db}_EXACT_EVOLUTION_summary.dat'
#
# File ~/Desktop/rsrch/qforte/src/qforte/ite/qite.py:390, in QITE.run(self, beta, db, dt, use_diis, max_diis_size, use_exact_evolution, expansion_type, evolve_dfham, random_state, sparseSb, low_memorySb, second_order, selected_pool, t_thresh, cumulative_t, b_thresh, x_thresh, conv_thresh, physical_r, folded_spectrum, BeH2_guess, e_shift, update_e_shift, do_lanczos, lanczos_gap, realistic_lanczos, fname, output_path, print_pool, use_cis_reference, target_root, cis_target_root)
#     387 timer = qf.local_timer()
#     388 timer.reset()
# --> 390 self.evolve()
#     392 timer.record('Total evolution time')
#     393 print(f"\n\n{timer}\n\n")
#
# File ~/Desktop/rsrch/qforte/src/qforte/ite/qite.py:1039, in QITE.evolve(self)
#    1036     print(f' {0.0:7.3f}    {self._Ekb[0]:+15.9f}    {self._n_classical_params:8}        {self._n_cnot:10}        {self._n_pauli_trm_measures:12}')
#    1038 if (self._print_summary_file):
# -> 1039     f = open(f"{self._output_path}qite_{self._fname}_summary.dat", "w+", buffering=1)
#    1040     f.write(f"#{'beta':>7}{'E(beta)':>18}{'N(params)':>14}{'N(CNOT)':>18}{'N(measure)':>20}\n")
#    1041     f.write('#-------------------------------------------------------------------------------\n')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/victorlucalita/src/my_qforte/2025_sqite/h10/ang_10/chain/qite_beta_0.0_db_0.1_fci_All_second_order_True_folded_spectrum_False_e_shift_None_selected_pool_True_t_1e-05_physical_r_True_dfham_False_summary.dat'

# %%
chain_path_1_t2 = run_qite(
    chain_mol_1,
    beta=0.0,
    db=0.1,
    expansion_type='All',
    second_order=True,
    selected_pool=True,
    t_thresh=theta_2,
    conv_thresh=1.0e-4,
    physical_r = True,
    output_path=c_path_1)

# %%
chain_path_1_t3 = run_qite(
    chain_mol_1,
    beta=0.0,
    db=0.1,
    expansion_type='All',
    second_order=True,
    selected_pool=True,
    t_thresh=theta_3,
    conv_thresh=1.0e-4,
    physical_r = True,
    output_path=c_path_1)

# %%
ring_path_1_t1 = run_qite(
    ring_mol_1,
    beta=0.0,
    db=0.1,
    expansion_type='All',
    second_order=True,
    selected_pool=True,
    t_thresh=theta_1,
    conv_thresh=1.0e-4,
    physical_r = True,
    output_path=r_path_1)

# %%
ring_path_1_t2 = run_qite(
    ring_mol_1,
    beta=0.0,
    db=0.1,
    expansion_type='All',
    second_order=True,
    selected_pool=True,
    t_thresh=theta_2,
    conv_thresh=1.0e-4,
    physical_r = True,
    output_path=r_path_1)

# %%
ring_path_1_t3 = run_qite(
    ring_mol_1,
    beta=0.0,
    db=0.1,
    expansion_type='All',
    second_order=True,
    selected_pool=True,
    t_thresh=theta_3,
    conv_thresh=1.0e-4,
    physical_r = True,
    output_path=r_path_1)

# %%
sheet_path_1_t1 = run_qite(
    sheet_mol_1,
    beta=0.0,
    db=0.1,
    expansion_type='All',
    second_order=True,
    selected_pool=True,
    t_thresh=theta_1,
    conv_thresh=1.0e-4,
    physical_r = True,
    output_path=s_path_1)

# %%
sheet_path_1_t2 = run_qite(
    sheet_mol_1,
    beta=0.0,
    db=0.1,
    expansion_type='All',
    second_order=True,
    selected_pool=True,
    t_thresh=theta_2,
    conv_thresh=1.0e-4,
    physical_r = True,
    output_path=s_path_1)

# %%
sheet_path_1_t3 = run_qite(
    sheet_mol_1,
    beta=0.0,
    db=0.1,
    expansion_type='All',
    second_order=True,
    selected_pool=True,
    t_thresh=theta_3,
    conv_thresh=1.0e-4,
    physical_r = True,
    output_path=s_path_1)

# %%
pyrmd_path_1_t1 = run_qite(
    pyrmd_mol_1,
    beta=0.0,
    db=0.1,
    expansion_type='All',
    second_order=True,
    selected_pool=True,
    t_thresh=theta_1,
    conv_thresh=1.0e-4,
    physical_r = True,
    output_path=p_path_1)

# %%
pyrmd_path_1_t2 = run_qite(
    pyrmd_mol_1,
    beta=0.0,
    db=0.1,
    expansion_type='All',
    second_order=True,
    selected_pool=True,
    t_thresh=theta_2,
    conv_thresh=1.0e-4,
    physical_r = True,
    output_path=p_path_1)

# %%
pyrmd_path_1_t3 = run_qite(
    pyrmd_mol_1,
    beta=0.0,
    db=0.1,
    expansion_type='All',
    second_order=True,
    selected_pool=True,
    t_thresh=theta_3,
    conv_thresh=1.0e-4,
    physical_r = True,
    output_path=p_path_1)

# %%
chain_path_15_t1 = run_qite(
    chain_mol_15,
    beta=0.0,
    db=0.1,
    expansion_type='All',
    second_order=True,
    selected_pool=True,
    t_thresh=theta_1,
    conv_thresh=1.0e-4,
    physical_r = True,
    output_path=c_path_15)

# %%
chain_path_15_t2 = run_qite(
    chain_mol_15,
    beta=0.0,
    db=0.1,
    expansion_type='All',
    second_order=True,
    selected_pool=True,
    t_thresh=theta_2,
    conv_thresh=1.0e-4,
    physical_r = True,
    output_path=c_path_15)

# %%
chain_path_15_t3 = run_qite(
    chain_mol_15,
    beta=0.0,
    db=0.1,
    expansion_type='All',
    second_order=True,
    selected_pool=True,
    t_thresh=theta_3,
    conv_thresh=1.0e-4,
    physical_r = True,
    output_path=c_path_15)

# %%
ring_path_15_t1 = run_qite(
    ring_mol_15,
    beta=0.0,
    db=0.1,
    expansion_type='All',
    second_order=True,
    selected_pool=True,
    t_thresh=theta_1,
    conv_thresh=1.0e-4,
    physical_r = True,
    output_path=r_path_15)

# %%
ring_path_15_t2 = run_qite(
    ring_mol_15,
    beta=0.0,
    db=0.1,
    expansion_type='All',
    second_order=True,
    selected_pool=True,
    t_thresh=theta_2,
    conv_thresh=1.0e-4,
    physical_r = True,
    output_path=r_path_15)

# %%
ring_path_15_t3 = run_qite(
    ring_mol_15,
    beta=0.0,
    db=0.1,
    expansion_type='All',
    second_order=True,
    selected_pool=True,
    t_thresh=theta_3,
    conv_thresh=1.0e-4,
    physical_r = True,
    output_path=r_path_15)

# %%
sheet_path_15_t1 = run_qite(
    sheet_mol_15,
    beta=0.0,
    db=0.1,
    expansion_type='All',
    second_order=True,
    selected_pool=True,
    t_thresh=theta_1,
    conv_thresh=1.0e-4,
    physical_r = True,
    output_path=s_path_15)

# %%
sheet_path_15_t2 = run_qite(
    sheet_mol_15,
    beta=0.0,
    db=0.1,
    expansion_type='All',
    second_order=True,
    selected_pool=True,
    t_thresh=theta_2,
    conv_thresh=1.0e-4,
    physical_r = True,
    output_path=s_path_15)

# %%
sheet_path_15_t3 = run_qite(
    sheet_mol_15,
    beta=0.0,
    db=0.1,
    expansion_type='All',
    second_order=True,
    selected_pool=True,
    t_thresh=theta_3,
    conv_thresh=1.0e-4,
    physical_r = True,
    output_path=s_path_15)

# %%
pyrmd_path_15_t1 = run_qite(
    pyrmd_mol_15,
    beta=0.0,
    db=0.1,
    expansion_type='All',
    second_order=True,
    selected_pool=True,
    t_thresh=theta_1,
    conv_thresh=1.0e-4,
    physical_r = True,
    output_path=p_path_15)

# %%
pyrmd_path_15_t2 = run_qite(
    pyrmd_mol_15,
    beta=0.0,
    db=0.1,
    expansion_type='All',
    second_order=True,
    selected_pool=True,
    t_thresh=theta_2,
    conv_thresh=1.0e-4,
    physical_r = True,
    output_path=p_path_15)

# %%
pyrmd_path_15_t3 = run_qite(
    pyrmd_mol_15,
    beta=0.0,
    db=0.1,
    expansion_type='All',
    second_order=True,
    selected_pool=True,
    t_thresh=theta_3,
    conv_thresh=1.0e-4,
    physical_r = True,
    output_path=p_path_15)

# %%
print(chain_path_1_t1)
print(chain_path_1_t2)
print(chain_path_1_t3)

print(ring_path_1_t1)
print(ring_path_1_t2)
print(ring_path_1_t3)

print(sheet_path_1_t1)
print(sheet_path_1_t2)
print(sheet_path_1_t3)

print(pyrmd_path_1_t1)
print(pyrmd_path_1_t2)
print(pyrmd_path_1_t3)

print(chain_path_15_t1)
print(chain_path_15_t2)
print(chain_path_15_t3)

print(ring_path_15_t1)
print(ring_path_15_t2)
print(ring_path_15_t3)

print(sheet_path_15_t1)
print(sheet_path_15_t2)
print(sheet_path_15_t3)

print(pyrmd_path_15_t1)
print(pyrmd_path_15_t2)
print(pyrmd_path_15_t3)
