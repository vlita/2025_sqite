# %%
import qforte as qf
import numpy as np
from geometries.chain_geom import get_h10chain_geom as chain
from geometries.ring_geom import get_h10ring_geom as ring
from geometries.sheet_geom import get_h10sheet_geom as sheet

import matplotlib.pyplot as plt
from read_data import read_qite as read

# %%
chain_mol_1 = qf.system_factory(build_type='psi4', mol_geometry=chain(1.0), basis='sto-6g', run_fci=True)
print(f'The FCI energy from Psi4:                                    {chain_mol_1.fci_energy:12.10f}')
print(f'The HF energy from Psi4:                                     {chain_mol_1.hf_energy:12.10f}')
ring_mol_1 = qf.system_factory(build_type='psi4', mol_geometry=ring(1.0), basis='sto-6g', run_fci=True)
print(f'The FCI energy from Psi4:                                    {ring_mol_1.fci_energy:12.10f}')
print(f'The HF energy from Psi4:                                     {ring_mol_1.hf_energy:12.10f}')
sheet_mol_1 = qf.system_factory(build_type='psi4', mol_geometry=sheet(1.0), basis='sto-6g', run_fci=True)
print(f'The FCI energy from Psi4:                                    {sheet_mol_1.fci_energy:12.10f}')
print(f'The HF energy from Psi4:                                     {sheet_mol_1.hf_energy:12.10f}')
chain_mol_15 = qf.system_factory(build_type='psi4', mol_geometry=chain(1.5), basis='sto-6g', run_fci=True)
print(f'The FCI energy from Psi4:                                    {chain_mol_15.fci_energy:12.10f}')
print(f'The HF energy from Psi4:                                     {chain_mol_15.hf_energy:12.10f}')
ring_mol_15 = qf.system_factory(build_type='psi4', mol_geometry=ring(1.5), basis='sto-6g', run_fci=True)
print(f'The FCI energy from Psi4:                                    {ring_mol_15.fci_energy:12.10f}')
print(f'The HF energy from Psi4:                                     {ring_mol_15.hf_energy:12.10f}')
sheet_mol_15 = qf.system_factory(build_type='psi4', mol_geometry=sheet(1.5), basis='sto-6g', run_fci=True)
print(f'The FCI energy from Psi4:                                    {sheet_mol_15.fci_energy:12.10f}')
print(f'The HF energy from Psi4:                                     {sheet_mol_15.hf_energy:12.10f}')
# Out:
#  ==> Psi4 geometry <==
# -------------------------
# 0  1
# H  0.0  0.0  4.5
# H  0.0  0.0  3.5
# H  0.0  0.0  2.5
# H  0.0  0.0  1.5
# H  0.0  0.0  0.5
# H  0.0  0.0  -0.5
# H  0.0  0.0  -1.5
# H  0.0  0.0  -2.5
# H  0.0  0.0  -3.5
# H  0.0  0.0  -4.5
# symmetry c1
# units angstrom
#
#   Memory set to   1.863 GiB by Python driver.
# The FCI energy from Psi4:                                    -5.4153933166
# The HF energy from Psi4:                                     -5.2476173423
#  ==> Psi4 geometry <==
# -------------------------
# 0  1
# H  1.618033988749895  0.0  0.0
# H  1.3090169943749475  0.9510565162951536  0.0
# H  0.5000000000000001  1.5388417685876268  0.0
# H  -0.4999999999999999  1.5388417685876268  0.0
# H  -1.3090169943749472  0.9510565162951538  0.0
# H  -1.618033988749895  1.9815201452341832e-16  0.0
# H  -1.3090169943749477  -0.9510565162951534  0.0
# H  -0.5000000000000002  -1.5388417685876268  0.0
# H  0.4999999999999997  -1.5388417685876268  0.0
# ...

# %%
c1_SD_path = '/home/vlita/2025_sqite/h10/ang_10/chain/qite_SD_selected_pool_False_t_1e-06_dfham_False_summary.dat'
c1_DT_path = '/home/vlita/2025_sqite/h10/ang_10/chain/qite_SDT_selected_pool_False_t_1e-06_dfham_False_summary.dat'
c1_t1_path = '/home/vlita/2025_sqite/h10/ang_10/chain/qite_All_selected_pool_True_t_1e-06_dfham_False_summary.dat'
c1_t2_path = '/home/vlita/2025_sqite/h10/ang_10/chain/qite_All_selected_pool_True_t_1e-07_dfham_False_summary.dat'
c1_t3_path = '/home/vlita/2025_sqite/h10/ang_10/chain/qite_All_selected_pool_True_t_5e-08_dfham_False_summary.dat'
c1_t4_path = '/home/vlita/2025_sqite/h10/ang_10/chain/qite_All_selected_pool_True_t_1e-08_dfham_False_summary.dat'

r1_SD_path = '/home/vlita/2025_sqite/h10/ang_10/ring/qite_SD_selected_pool_False_t_1e-06_dfham_False_summary.dat'
r1_DT_path = '/home/vlita/2025_sqite/h10/ang_10/ring/qite_SDT_selected_pool_False_t_1e-06_dfham_False_summary.dat'
r1_t1_path = '/home/vlita/2025_sqite/h10/ang_10/ring/qite_All_selected_pool_True_t_1e-06_dfham_False_summary.dat'
r1_t2_path = '/home/vlita/2025_sqite/h10/ang_10/ring/qite_All_selected_pool_True_t_1e-07_dfham_False_summary.dat'
r1_t3_path = '/home/vlita/2025_sqite/h10/ang_10/ring/qite_All_selected_pool_True_t_5e-08_dfham_False_summary.dat'
r1_t4_path = '/home/vlita/2025_sqite/h10/ang_10/ring/qite_All_selected_pool_True_t_1e-08_dfham_False_summary.dat'

s1_SD_path = '/home/vlita/2025_sqite/h10/ang_10/sheet/qite_SD_selected_pool_False_t_1e-06_dfham_False_summary.dat'
s1_DT_path = '/home/vlita/2025_sqite/h10/ang_10/sheet/qite_SDT_selected_pool_False_t_1e-06_dfham_False_summary.dat'
s1_t1_path = '/home/vlita/2025_sqite/h10/ang_10/sheet/qite_All_selected_pool_True_t_1e-06_dfham_False_summary.dat'
s1_t2_path = '/home/vlita/2025_sqite/h10/ang_10/sheet/qite_All_selected_pool_True_t_1e-07_dfham_False_summary.dat'
s1_t3_path = '/home/vlita/2025_sqite/h10/ang_10/sheet/qite_All_selected_pool_True_t_5e-08_dfham_False_summary.dat'
s1_t4_path = '/home/vlita/2025_sqite/h10/ang_10/sheet/qite_All_selected_pool_True_t_1e-08_dfham_False_summary.dat'

c15_SD_path = '/home/vlita/2025_sqite/h10/ang_15/chain/qite_SD_selected_pool_False_t_1e-06_dfham_False_summary.dat'
c15_DT_path = '/home/vlita/2025_sqite/h10/ang_15/chain/qite_SDT_selected_pool_False_t_1e-06_dfham_False_summary.dat'
c15_t1_path = '/home/vlita/2025_sqite/h10/ang_15/chain/qite_All_selected_pool_True_t_1e-06_dfham_False_summary.dat'
c15_t2_path = '/home/vlita/2025_sqite/h10/ang_15/chain/qite_All_selected_pool_True_t_1e-07_dfham_False_summary.dat'
c15_t3_path = '/home/vlita/2025_sqite/h10/ang_15/chain/qite_All_selected_pool_True_t_5e-08_dfham_False_summary.dat'
c15_t4_path = '/home/vlita/2025_sqite/h10/ang_15/chain/qite_All_selected_pool_True_t_1e-08_dfham_False_summary.dat'

r15_SD_path = '/home/vlita/2025_sqite/h10/ang_15/ring/qite_SD_selected_pool_False_t_1e-06_dfham_False_summary.dat'
r15_DT_path = '/home/vlita/2025_sqite/h10/ang_15/ring/qite_SDT_selected_pool_False_t_1e-06_dfham_False_summary.dat'
r15_t1_path = '/home/vlita/2025_sqite/h10/ang_15/ring/qite_All_selected_pool_True_t_1e-06_dfham_False_summary.dat'
r15_t2_path = '/home/vlita/2025_sqite/h10/ang_15/ring/qite_All_selected_pool_True_t_1e-07_dfham_False_summary.dat'
r15_t3_path = '/home/vlita/2025_sqite/h10/ang_15/ring/qite_All_selected_pool_True_t_5e-08_dfham_False_summary.dat'
r15_t4_path = '/home/vlita/2025_sqite/h10/ang_15/ring/qite_All_selected_pool_True_t_1e-08_dfham_False_summary.dat'

s15_SD_path = '/home/vlita/2025_sqite/h10/ang_15/sheet/qite_SD_selected_pool_False_t_1e-06_dfham_False_summary.dat'
s15_DT_path = '/home/vlita/2025_sqite/h10/ang_15/sheet/qite_SDT_selected_pool_False_t_1e-06_dfham_False_summary.dat'
s15_t1_path = '/home/vlita/2025_sqite/h10/ang_15/sheet/qite_All_selected_pool_True_t_1e-06_dfham_False_summary.dat'
s15_t2_path = '/home/vlita/2025_sqite/h10/ang_15/sheet/qite_All_selected_pool_True_t_1e-07_dfham_False_summary.dat'
s15_t3_path = '/home/vlita/2025_sqite/h10/ang_15/sheet/qite_All_selected_pool_True_t_5e-08_dfham_False_summary.dat'
s15_t4_path = '/home/vlita/2025_sqite/h10/ang_15/sheet/qite_All_selected_pool_True_t_1e-08_dfham_False_summary.dat'

# %%
c1_SD_b, c1_SD_e, c1_SD_p, c1_SD_c, c1_SD_m = read(c1_SD_path)
c1_DT_b, c1_DT_e, c1_DT_p, c1_DT_c, c1_DT_m = read(c1_DT_path)
c1_t1_b, c1_t1_e, c1_t1_p, c1_t1_c, c1_t1_m = read(c1_t1_path)
c1_t2_b, c1_t2_e, c1_t2_p, c1_t2_c, c1_t2_m = read(c1_t2_path)
c1_t3_b, c1_t3_e, c1_t3_p, c1_t3_c, c1_t3_m = read(c1_t3_path)
c1_t4_b, c1_t4_e, c1_t4_p, c1_t4_c, c1_t4_m = read(c1_t4_path)

r1_SD_b, r1_SD_e, r1_SD_p, r1_SD_c, r1_SD_m = read(r1_SD_path)
r1_DT_b, r1_DT_e, r1_DT_p, r1_DT_c, r1_DT_m = read(r1_DT_path)
r1_t1_b, r1_t1_e, r1_t1_p, r1_t1_c, r1_t1_m = read(r1_t1_path)
r1_t2_b, r1_t2_e, r1_t2_p, r1_t2_c, r1_t2_m = read(r1_t2_path)
r1_t3_b, r1_t3_e, r1_t3_p, r1_t3_c, r1_t3_m = read(r1_t3_path)
r1_t4_b, r1_t4_e, r1_t4_p, r1_t4_c, r1_t4_m = read(r1_t4_path)

s1_SD_b, s1_SD_e, s1_SD_p, s1_SD_c, s1_SD_m = read(s1_SD_path)
s1_DT_b, s1_DT_e, s1_DT_p, s1_DT_c, s1_DT_m = read(s1_DT_path)
s1_t1_b, s1_t1_e, s1_t1_p, s1_t1_c, s1_t1_m = read(s1_t1_path)
s1_t2_b, s1_t2_e, s1_t2_p, s1_t2_c, s1_t2_m = read(s1_t2_path)
s1_t3_b, s1_t3_e, s1_t3_p, s1_t3_c, s1_t3_m = read(s1_t3_path)
s1_t4_b, s1_t4_e, s1_t4_p, s1_t4_c, s1_t4_m = read(s1_t4_path)

c15_SD_b, c15_SD_e, c15_SD_p, c15_SD_c, c15_SD_m = read(c15_SD_path)
c15_DT_b, c15_DT_e, c15_DT_p, c15_DT_c, c15_DT_m = read(c15_DT_path)
c15_t1_b, c15_t1_e, c15_t1_p, c15_t1_c, c15_t1_m = read(c15_t1_path)
c15_t2_b, c15_t2_e, c15_t2_p, c15_t2_c, c15_t2_m = read(c15_t2_path)
c15_t3_b, c15_t3_e, c15_t3_p, c15_t3_c, c15_t3_m = read(c15_t3_path)
c15_t4_b, c15_t4_e, c15_t4_p, c15_t4_c, c15_t4_m = read(c15_t4_path)

r15_SD_b, r15_SD_e, r15_SD_p, r15_SD_c, r15_SD_m = read(r15_SD_path)
r15_DT_b, r15_DT_e, r15_DT_p, r15_DT_c, r15_DT_m = read(r15_DT_path)
r15_t1_b, r15_t1_e, r15_t1_p, r15_t1_c, r15_t1_m = read(r15_t1_path)
r15_t2_b, r15_t2_e, r15_t2_p, r15_t2_c, r15_t2_m = read(r15_t2_path)
r15_t3_b, r15_t3_e, r15_t3_p, r15_t3_c, r15_t3_m = read(r15_t3_path)
r15_t4_b, r15_t4_e, r15_t4_p, r15_t4_c, r15_t4_m = read(r15_t4_path)

s15_SD_b, s15_SD_e, s15_SD_p, s15_SD_c, s15_SD_m = read(s15_SD_path)
s15_DT_b, s15_DT_e, s15_DT_p, s15_DT_c, s15_DT_m = read(s15_DT_path)
s15_t1_b, s15_t1_e, s15_t1_p, s15_t1_c, s15_t1_m = read(s15_t1_path)
s15_t2_b, s15_t2_e, s15_t2_p, s15_t2_c, s15_t2_m = read(s15_t2_path)
s15_t3_b, s15_t3_e, s15_t3_p, s15_t3_c, s15_t3_m = read(s15_t3_path)
s15_t4_b, s15_t4_e, s15_t4_p, s15_t4_c, s15_t4_m = read(s15_t4_path)

# %%
c1_SD_e = [abs(float(item) - chain_mol_1.fci_energy) for item in c1_SD_e]
c1_DT_e = [abs(float(item) - chain_mol_1.fci_energy) for item in c1_DT_e]
c1_t1_e = [abs(float(item) - chain_mol_1.fci_energy) for item in c1_t1_e]
c1_t2_e = [abs(float(item) - chain_mol_1.fci_energy) for item in c1_t2_e]
c1_t3_e = [abs(float(item) - chain_mol_1.fci_energy) for item in c1_t3_e]
c1_t4_e = [abs(float(item) - chain_mol_1.fci_energy) for item in c1_t4_e]

c1_SD_m = [int(item) for item in c1_SD_m]
c1_DT_m = [int(item) for item in c1_DT_m]
c1_t1_m = [int(item) for item in c1_t1_m]
c1_t2_m = [int(item) for item in c1_t2_m]
c1_t3_m = [int(item) for item in c1_t3_m]
c1_t4_m = [int(item) for item in c1_t4_m]

c1_SD_c = [int(item) for item in c1_SD_c]
c1_DT_c = [int(item) for item in c1_DT_c]
c1_t1_c = [int(item) for item in c1_t1_c]
c1_t2_c = [int(item) for item in c1_t2_c]
c1_t3_c = [int(item) for item in c1_t3_c]
c1_t4_c = [int(item) for item in c1_t4_c]

c1_SD_p = [int(item) for item in c1_SD_p]
c1_DT_p = [int(item) for item in c1_DT_p]
c1_t1_p = [int(item) for item in c1_t1_p]
c1_t2_p = [int(item) for item in c1_t2_p]
c1_t3_p = [int(item) for item in c1_t3_p]
c1_t4_p = [int(item) for item in c1_t4_p]

c1_SD_b = [float(item) for item in c1_SD_b]
c1_DT_b = [float(item) for item in c1_DT_b]
c1_t1_b = [float(item) for item in c1_t1_b]
c1_t2_b = [float(item) for item in c1_t2_b]
c1_t3_b = [float(item) for item in c1_t3_b]
c1_t4_b = [float(item) for item in c1_t4_b]

r1_SD_e = [abs(float(item) - ring_mol_1.fci_energy) for item in r1_SD_e]
r1_DT_e = [abs(float(item) - ring_mol_1.fci_energy) for item in r1_DT_e]
r1_t1_e = [abs(float(item) - ring_mol_1.fci_energy) for item in r1_t1_e]
r1_t2_e = [abs(float(item) - ring_mol_1.fci_energy) for item in r1_t2_e]
r1_t3_e = [abs(float(item) - ring_mol_1.fci_energy) for item in r1_t3_e]
r1_t4_e = [abs(float(item) - ring_mol_1.fci_energy) for item in r1_t4_e]

r1_SD_m = [int(item) for item in r1_SD_m]
r1_DT_m = [int(item) for item in r1_DT_m]
r1_t1_m = [int(item) for item in r1_t1_m]
r1_t2_m = [int(item) for item in r1_t2_m]
r1_t3_m = [int(item) for item in r1_t3_m]
r1_t4_m = [int(item) for item in r1_t4_m]

r1_SD_c = [int(item) for item in r1_SD_c]
r1_DT_c = [int(item) for item in r1_DT_c]
r1_t1_c = [int(item) for item in r1_t1_c]
r1_t2_c = [int(item) for item in r1_t2_c]
r1_t3_c = [int(item) for item in r1_t3_c]
r1_t4_c = [int(item) for item in r1_t4_c]

r1_SD_p = [int(item) for item in r1_SD_p]
r1_DT_p = [int(item) for item in r1_DT_p]
r1_t1_p = [int(item) for item in r1_t1_p]
r1_t2_p = [int(item) for item in r1_t2_p]
r1_t3_p = [int(item) for item in r1_t3_p]
r1_t4_p = [int(item) for item in r1_t4_p]

r1_SD_b = [float(item) for item in r1_SD_b]
r1_DT_b = [float(item) for item in r1_DT_b]
r1_t1_b = [float(item) for item in r1_t1_b]
r1_t2_b = [float(item) for item in r1_t2_b]
r1_t3_b = [float(item) for item in r1_t3_b]
r1_t4_b = [float(item) for item in r1_t4_b]

s1_SD_e = [abs(float(item) - sheet_mol_1.fci_energy) for item in s1_SD_e]
s1_DT_e = [abs(float(item) - sheet_mol_1.fci_energy) for item in s1_DT_e]
s1_t1_e = [abs(float(item) - sheet_mol_1.fci_energy) for item in s1_t1_e]
s1_t2_e = [abs(float(item) - sheet_mol_1.fci_energy) for item in s1_t2_e]
s1_t3_e = [abs(float(item) - sheet_mol_1.fci_energy) for item in s1_t3_e]
s1_t4_e = [abs(float(item) - sheet_mol_1.fci_energy) for item in s1_t4_e]

s1_SD_m = [int(item) for item in s1_SD_m]
s1_DT_m = [int(item) for item in s1_DT_m]
s1_t1_m = [int(item) for item in s1_t1_m]
s1_t2_m = [int(item) for item in s1_t2_m]
s1_t3_m = [int(item) for item in s1_t3_m]
s1_t4_m = [int(item) for item in s1_t4_m]

s1_SD_c = [int(item) for item in s1_SD_c]
s1_DT_c = [int(item) for item in s1_DT_c]
s1_t1_c = [int(item) for item in s1_t1_c]
s1_t2_c = [int(item) for item in s1_t2_c]
s1_t3_c = [int(item) for item in s1_t3_c]
s1_t4_c = [int(item) for item in s1_t4_c]

s1_SD_p = [int(item) for item in s1_SD_p]
s1_DT_p = [int(item) for item in s1_DT_p]
s1_t1_p = [int(item) for item in s1_t1_p]
s1_t2_p = [int(item) for item in s1_t2_p]
s1_t3_p = [int(item) for item in s1_t3_p]
s1_t4_p = [int(item) for item in s1_t4_p]

s1_SD_b = [float(item) for item in s1_SD_b]
s1_DT_b = [float(item) for item in s1_DT_b]
s1_t1_b = [float(item) for item in s1_t1_b]
s1_t2_b = [float(item) for item in s1_t2_b]
s1_t3_b = [float(item) for item in s1_t3_b]
s1_t4_b = [float(item) for item in s1_t4_b]

c15_SD_e = [abs(float(item) - chain_mol_15.fci_energy) for item in c15_SD_e]
c15_DT_e = [abs(float(item) - chain_mol_15.fci_energy) for item in c15_DT_e]
c15_t1_e = [abs(float(item) - chain_mol_15.fci_energy) for item in c15_t1_e]
c15_t2_e = [abs(float(item) - chain_mol_15.fci_energy) for item in c15_t2_e]
c15_t3_e = [abs(float(item) - chain_mol_15.fci_energy) for item in c15_t3_e]
c15_t4_e = [abs(float(item) - chain_mol_15.fci_energy) for item in c15_t4_e]

c15_SD_m = [int(item) for item in c15_SD_m]
c15_DT_m = [int(item) for item in c15_DT_m]
c15_t1_m = [int(item) for item in c15_t1_m]
c15_t2_m = [int(item) for item in c15_t2_m]
c15_t3_m = [int(item) for item in c15_t3_m]
c15_t4_m = [int(item) for item in c15_t4_m]

c15_SD_c = [int(item) for item in c15_SD_c]
c15_DT_c = [int(item) for item in c15_DT_c]
c15_t1_c = [int(item) for item in c15_t1_c]
c15_t2_c = [int(item) for item in c15_t2_c]
c15_t3_c = [int(item) for item in c15_t3_c]
c15_t4_c = [int(item) for item in c15_t4_c]

c15_SD_p = [int(item) for item in c15_SD_p]
c15_DT_p = [int(item) for item in c15_DT_p]
c15_t1_p = [int(item) for item in c15_t1_p]
c15_t2_p = [int(item) for item in c15_t2_p]
c15_t3_p = [int(item) for item in c15_t3_p]
c15_t4_p = [int(item) for item in c15_t4_p]

c15_SD_b = [float(item) for item in c15_SD_b]
c15_DT_b = [float(item) for item in c15_DT_b]
c15_t1_b = [float(item) for item in c15_t1_b]
c15_t2_b = [float(item) for item in c15_t2_b]
c15_t3_b = [float(item) for item in c15_t3_b]
c15_t4_b = [float(item) for item in c15_t4_b]

r15_SD_e = [abs(float(item) - ring_mol_15.fci_energy) for item in r15_SD_e]
r15_DT_e = [abs(float(item) - ring_mol_15.fci_energy) for item in r15_DT_e]
r15_t1_e = [abs(float(item) - ring_mol_15.fci_energy) for item in r15_t1_e]
r15_t2_e = [abs(float(item) - ring_mol_15.fci_energy) for item in r15_t2_e]
r15_t3_e = [abs(float(item) - ring_mol_15.fci_energy) for item in r15_t3_e]
r15_t4_e = [abs(float(item) - ring_mol_15.fci_energy) for item in r15_t4_e]

r15_SD_m = [int(item) for item in r15_SD_m]
r15_DT_m = [int(item) for item in r15_DT_m]
r15_t1_m = [int(item) for item in r15_t1_m]
r15_t2_m = [int(item) for item in r15_t2_m]
r15_t3_m = [int(item) for item in r15_t3_m]
r15_t4_m = [int(item) for item in r15_t4_m]

r15_SD_c = [int(item) for item in r15_SD_c]
r15_DT_c = [int(item) for item in r15_DT_c]
r15_t1_c = [int(item) for item in r15_t1_c]
r15_t2_c = [int(item) for item in r15_t2_c]
r15_t3_c = [int(item) for item in r15_t3_c]
r15_t4_c = [int(item) for item in r15_t4_c]

r15_SD_p = [int(item) for item in r15_SD_p]
r15_DT_p = [int(item) for item in r15_DT_p]
r15_t1_p = [int(item) for item in r15_t1_p]
r15_t2_p = [int(item) for item in r15_t2_p]
r15_t3_p = [int(item) for item in r15_t3_p]
r15_t4_p = [int(item) for item in r15_t4_p]

r15_SD_b = [float(item) for item in r15_SD_b]
r15_DT_b = [float(item) for item in r15_DT_b]
r15_t1_b = [float(item) for item in r15_t1_b]
r15_t2_b = [float(item) for item in r15_t2_b]
r15_t3_b = [float(item) for item in r15_t3_b]
r15_t4_b = [float(item) for item in r15_t4_b]

s15_SD_e = [abs(float(item) - sheet_mol_15.fci_energy) for item in s15_SD_e]
s15_DT_e = [abs(float(item) - sheet_mol_15.fci_energy) for item in s15_DT_e]
s15_t1_e = [abs(float(item) - sheet_mol_15.fci_energy) for item in s15_t1_e]
s15_t2_e = [abs(float(item) - sheet_mol_15.fci_energy) for item in s15_t2_e]
s15_t3_e = [abs(float(item) - sheet_mol_15.fci_energy) for item in s15_t3_e]
s15_t4_e = [abs(float(item) - sheet_mol_15.fci_energy) for item in s15_t4_e]

s15_SD_m = [int(item) for item in s15_SD_m]
s15_DT_m = [int(item) for item in s15_DT_m]
s15_t1_m = [int(item) for item in s15_t1_m]
s15_t2_m = [int(item) for item in s15_t2_m]
s15_t3_m = [int(item) for item in s15_t3_m]
s15_t4_m = [int(item) for item in s15_t4_m]

s15_SD_c = [int(item) for item in s15_SD_c]
s15_DT_c = [int(item) for item in s15_DT_c]
s15_t1_c = [int(item) for item in s15_t1_c]
s15_t2_c = [int(item) for item in s15_t2_c]
s15_t3_c = [int(item) for item in s15_t3_c]
s15_t4_c = [int(item) for item in s15_t4_c]

s15_SD_p = [int(item) for item in s15_SD_p]
s15_DT_p = [int(item) for item in s15_DT_p]
s15_t1_p = [int(item) for item in s15_t1_p]
s15_t2_p = [int(item) for item in s15_t2_p]
s15_t3_p = [int(item) for item in s15_t3_p]
s15_t4_p = [int(item) for item in s15_t4_p]

s15_SD_b = [float(item) for item in s15_SD_b]
s15_DT_b = [float(item) for item in s15_DT_b]
s15_t1_b = [float(item) for item in s15_t1_b]
s15_t2_b = [float(item) for item in s15_t2_b]
s15_t3_b = [float(item) for item in s15_t3_b]
s15_t4_b = [float(item) for item in s15_t4_b]

# %%
# Create 2x2 subplot grid
fig, axs = plt.subplots(2, 2, figsize=(12, 10))

axs[0, 0].semilogy(c1_SD_b, c1_SD_e, linestyle='-', color='black', label='SD')
axs[0, 0].semilogy(c1_DT_b, c1_DT_e, linestyle='-', color='brown', label='SDT')
axs[0, 0].semilogy(c1_t3_b, c1_t3_e, linestyle='-', color='red', label='t3')
axs[0, 0].semilogy(c1_t2_b, c1_t2_e, linestyle='-', color='green', label='t2')
axs[0, 0].semilogy(c1_t1_b, c1_t1_e, linestyle='-', color='blue', label='t1')
axs[0, 0].semilogy(c1_t4_b, c1_t4_e, linestyle='-', color='purple', label='t4')
axs[0, 0].axhline(y=1.6e-3, color='gray', linestyle=':', linewidth=1, label='Chemical Accuracy')
# axs[0, 0].set_title('log10 Energy vs beta')
axs[0, 0].set_xlabel(r'$ \beta $(a. u.)')
axs[0, 0].set_ylabel('Energy Error / $mE_{h}$')
# axs[0, 0].legend()

axs[0, 1].semilogy(c1_SD_p, c1_SD_e, linestyle='-', color='black', label='SD')
axs[0, 1].semilogy(c1_DT_p, c1_DT_e, linestyle='-', color='brown', label='SDT')
axs[0, 1].semilogy(c1_t3_p, c1_t3_e, linestyle='-', color='red', label='t3')
axs[0, 1].semilogy(c1_t2_p, c1_t2_e, linestyle='-', color='green', label='t2')
axs[0, 1].semilogy(c1_t1_p, c1_t1_e, linestyle='-', color='blue', label='t1')
axs[0, 1].semilogy(c1_t4_p, c1_t4_e, linestyle='-', color='purple', label='t4')
axs[0, 1].axhline(y=1.6e-3, color='gray', linestyle=':', linewidth=1, label='Chemical Accuracy')
# axs[0, 1].set_title('log10 Energy vs params')
axs[0, 1].set_xlabel('$N_{par}$')
axs[0, 1].set_ylabel('Energy Error / $mE_{h}$')
# axs[0, 1].legend()

axs[1, 0].loglog(c1_SD_m, c1_SD_e, linestyle='-', color='black', label='SD')
axs[1, 0].loglog(c1_DT_m, c1_DT_e, linestyle='-', color='brown', label='SDT')
axs[1, 0].loglog(c1_t3_m, c1_t3_e, linestyle='-', color='red', label='t3')
axs[1, 0].loglog(c1_t2_m, c1_t2_e, linestyle='-', color='green', label='t2')
axs[1, 0].loglog(c1_t1_m, c1_t1_e, linestyle='-', color='blue', label='t1')
axs[1, 0].loglog(c1_t4_m, c1_t4_e, linestyle='-', color='purple', label='t4')
axs[1, 0].axhline(y=1.6e-3, color='gray', linestyle=':', linewidth=1, label='Chemical Accuracy')
# axs[1, 0].set_title('log10 Energy vs pauli')
axs[1, 0].set_xlabel('$N_{meas}$')
axs[1, 0].set_ylabel('Energy Error / $mE_{h}$')
# axs[1, 0].legend()

axs[1, 1].loglog(c1_SD_c, c1_SD_e, linestyle='-', color='black', label='SD')
axs[1, 1].loglog(c1_DT_c, c1_DT_e, linestyle='-', color='brown', label='SDT')
axs[1, 1].loglog(c1_t3_c, c1_t3_e, linestyle='-', color='red', label='t3')
axs[1, 1].loglog(c1_t2_c, c1_t2_e, linestyle='-', color='green', label='t2')
axs[1, 1].loglog(c1_t1_c, c1_t1_e, linestyle='-', color='blue', label='t1')
axs[1, 1].loglog(c1_t4_c, c1_t4_e, linestyle='-', color='purple', label='t4')
axs[1, 1].axhline(y=1.6e-3, color='gray', linestyle=':', linewidth=1, label='Chemical Accuracy')
# axs[1, 1].set_title('log10 Energy vs cnot')
axs[1, 1].set_xlabel('$N_{CNOT}$')
axs[1, 1].set_ylabel('Energy Error / $mE_{h}$')
# axs[1, 1].legend()

# fig.suptitle("Chain 1.0A", fontsize=16)
# Adjust layout and show plot
plt.tight_layout()
plt.show()

# %%
# Create 2x2 subplot grid
fig, axs = plt.subplots(2, 2, figsize=(12, 10))

axs[0, 0].semilogy(r1_SD_b, r1_SD_e, linestyle='-', color='black', label='SD')
axs[0, 0].semilogy(r1_DT_b, r1_DT_e, linestyle='-', color='brown', label='SDT')
axs[0, 0].semilogy(r1_t3_b, r1_t3_e, linestyle='-', color='red', label='t3')
axs[0, 0].semilogy(r1_t2_b, r1_t2_e, linestyle='-', color='green', label='t2')
axs[0, 0].semilogy(r1_t1_b, r1_t1_e, linestyle='-', color='blue', label='t1')
axs[0, 0].semilogy(r1_t4_b, r1_t4_e, linestyle='-', color='purple', label='t4')
axs[0, 0].axhline(y=1.6e-3, color='gray', linestyle=':', linewidth=1, label='Chemical Accuracy')
# axs[0, 0].set_title('log10 Energy vs beta')
axs[0, 0].set_xlabel(r'$ \beta $(a. u.)')
axs[0, 0].set_ylabel('Energy Error / $mE_{h}$')
# axs[0, 0].legend()

axs[0, 1].semilogy(r1_SD_p, r1_SD_e, linestyle='-', color='black', label='SD')
axs[0, 1].semilogy(r1_DT_p, r1_DT_e, linestyle='-', color='brown', label='SDT')
axs[0, 1].semilogy(r1_t3_p, r1_t3_e, linestyle='-', color='red', label='t3')
axs[0, 1].semilogy(r1_t2_p, r1_t2_e, linestyle='-', color='green', label='t2')
axs[0, 1].semilogy(r1_t1_p, r1_t1_e, linestyle='-', color='blue', label='t1')
axs[0, 1].semilogy(r1_t4_p, r1_t4_e, linestyle='-', color='purple', label='t4')
axs[0, 1].axhline(y=1.6e-3, color='gray', linestyle=':', linewidth=1, label='Chemical Accuracy')
# axs[0, 1].set_title('log10 Energy vs params')
axs[0, 1].set_xlabel('$N_{par}$')
axs[0, 1].set_ylabel('Energy Error / $mE_{h}$')
# axs[0, 1].legend()

axs[1, 0].loglog(r1_SD_m, r1_SD_e, linestyle='-', color='black', label='SD')
axs[1, 0].loglog(r1_DT_m, r1_DT_e, linestyle='-', color='brown', label='SDT')
axs[1, 0].loglog(r1_t3_m, r1_t3_e, linestyle='-', color='red', label='t3')
axs[1, 0].loglog(r1_t2_m, r1_t2_e, linestyle='-', color='green', label='t2')
axs[1, 0].loglog(r1_t1_m, r1_t1_e, linestyle='-', color='blue', label='t1')
axs[1, 0].loglog(r1_t4_m, r1_t4_e, linestyle='-', color='purple', label='t4')
axs[1, 0].axhline(y=1.6e-3, color='gray', linestyle=':', linewidth=1, label='Chemical Accuracy')
# axs[1, 0].set_title('log10 Energy vs pauli')
axs[1, 0].set_xlabel('$N_{meas}$')
axs[1, 0].set_ylabel('Energy Error / $mE_{h}$')
# axs[1, 0].legend()

axs[1, 1].loglog(r1_SD_c, r1_SD_e, linestyle='-', color='black', label='SD')
axs[1, 1].loglog(r1_DT_c, r1_DT_e, linestyle='-', color='brown', label='SDT')
axs[1, 1].loglog(r1_t3_c, r1_t3_e, linestyle='-', color='red', label='t3')
axs[1, 1].loglog(r1_t2_c, r1_t2_e, linestyle='-', color='green', label='t2')
axs[1, 1].loglog(r1_t1_c, r1_t1_e, linestyle='-', color='blue', label='t1')
axs[1, 1].loglog(r1_t4_c, r1_t4_e, linestyle='-', color='purple', label='t4')
axs[1, 1].axhline(y=1.6e-3, color='gray', linestyle=':', linewidth=1, label='Chemical Accuracy')
# axs[1, 1].set_title('log10 Energy vs cnot')
axs[1, 1].set_xlabel('$N_{CNOT}$')
axs[1, 1].set_ylabel('Energy Error / $mE_{h}$')
# axs[1, 1].legend()

# fig.suptitle("Chain 1.0A", fontsize=16)
# Adjust layout and show plot
plt.tight_layout()
plt.show()

# %%
# Create 2x2 subplot grid
fig, axs = plt.subplots(2, 2, figsize=(12, 10))

axs[0, 0].semilogy(s1_SD_b, s1_SD_e, linestyle='-', color='black', label='SD')
axs[0, 0].semilogy(s1_DT_b, s1_DT_e, linestyle='-', color='brown', label='SDT')
axs[0, 0].semilogy(s1_t3_b, s1_t3_e, linestyle='-', color='red', label='t3')
axs[0, 0].semilogy(s1_t2_b, s1_t2_e, linestyle='-', color='green', label='t2')
axs[0, 0].semilogy(s1_t1_b, s1_t1_e, linestyle='-', color='blue', label='t1')
axs[0, 0].semilogy(s1_t4_b, s1_t4_e, linestyle='-', color='purple', label='t4')
axs[0, 0].axhline(y=1.6e-3, color='gray', linestyle=':', linewidth=1, label='Chemical Accuracy')
# axs[0, 0].set_title('log10 Energy vs beta')
axs[0, 0].set_xlabel(r'$ \beta $(a. u.)')
axs[0, 0].set_ylabel('Energy Error / $mE_{h}$')
# axs[0, 0].legend()

axs[0, 1].semilogy(s1_SD_p, s1_SD_e, linestyle='-', color='black', label='SD')
axs[0, 1].semilogy(s1_DT_p, s1_DT_e, linestyle='-', color='brown', label='SDT')
axs[0, 1].semilogy(s1_t3_p, s1_t3_e, linestyle='-', color='red', label='t3')
axs[0, 1].semilogy(s1_t2_p, s1_t2_e, linestyle='-', color='green', label='t2')
axs[0, 1].semilogy(s1_t1_p, s1_t1_e, linestyle='-', color='blue', label='t1')
axs[0, 1].semilogy(s1_t4_p, s1_t4_e, linestyle='-', color='purple', label='t4')
axs[0, 1].axhline(y=1.6e-3, color='gray', linestyle=':', linewidth=1, label='Chemical Accuracy')
# axs[0, 1].set_title('log10 Energy vs params')
axs[0, 1].set_xlabel('$N_{par}$')
axs[0, 1].set_ylabel('Energy Error / $mE_{h}$')
# axs[0, 1].legend()

axs[1, 0].loglog(s1_SD_m, s1_SD_e, linestyle='-', color='black', label='SD')
axs[1, 0].loglog(s1_DT_m, s1_DT_e, linestyle='-', color='brown', label='SDT')
axs[1, 0].loglog(s1_t3_m, s1_t3_e, linestyle='-', color='red', label='t3')
axs[1, 0].loglog(s1_t2_m, s1_t2_e, linestyle='-', color='green', label='t2')
axs[1, 0].loglog(s1_t1_m, s1_t1_e, linestyle='-', color='blue', label='t1')
axs[1, 0].loglog(s1_t4_m, s1_t4_e, linestyle='-', color='purple', label='t4')
axs[1, 0].axhline(y=1.6e-3, color='gray', linestyle=':', linewidth=1, label='Chemical Accuracy')
# axs[1, 0].set_title('log10 Energy vs pauli')
axs[1, 0].set_xlabel('$N_{meas}$')
axs[1, 0].set_ylabel('Energy Error / $mE_{h}$')
# axs[1, 0].legend()

axs[1, 1].loglog(s1_SD_c, s1_SD_e, linestyle='-', color='black', label='SD')
axs[1, 1].loglog(s1_DT_c, s1_DT_e, linestyle='-', color='brown', label='SDT')
axs[1, 1].loglog(s1_t3_c, s1_t3_e, linestyle='-', color='red', label='t3')
axs[1, 1].loglog(s1_t2_c, s1_t2_e, linestyle='-', color='green', label='t2')
axs[1, 1].loglog(s1_t1_c, s1_t1_e, linestyle='-', color='blue', label='t1')
axs[1, 1].loglog(s1_t4_c, s1_t4_e, linestyle='-', color='purple', label='t4')
axs[1, 1].axhline(y=1.6e-3, color='gray', linestyle=':', linewidth=1, label='Chemical Accuracy')
# axs[1, 1].set_title('log10 Energy vs cnot')
axs[1, 1].set_xlabel('$N_{CNOT}$')
axs[1, 1].set_ylabel('Energy Error / $mE_{h}$')
# axs[1, 1].legend()

# fig.suptitle("Chain 1.0A", fontsize=16)
# Adjust layout and show plot
plt.tight_layout()
plt.show()

# %%
# Create 2x2 subplot grid
fig, axs = plt.subplots(2, 2, figsize=(12, 10))

axs[0, 0].semilogy(c15_SD_b, c15_SD_e, linestyle='-', color='black', label='SD')
axs[0, 0].semilogy(c15_DT_b, c15_DT_e, linestyle='-', color='brown', label='SDT')
axs[0, 0].semilogy(c15_t3_b, c15_t3_e, linestyle='-', color='red', label='t3')
axs[0, 0].semilogy(c15_t2_b, c15_t2_e, linestyle='-', color='green', label='t2')
axs[0, 0].semilogy(c15_t1_b, c15_t1_e, linestyle='-', color='blue', label='t1')
axs[0, 0].semilogy(c15_t4_b, c15_t4_e, linestyle='-', color='purple', label='t4')
axs[0, 0].axhline(y=1.6e-3, color='gray', linestyle=':', linewidth=1, label='Chemical Accuracy')
# axs[0, 0].set_title('log10 Energy vs beta')
axs[0, 0].set_xlabel(r'$ \beta $(a. u.)')
axs[0, 0].set_ylabel('Energy Error / $mE_{h}$')
# axs[0, 0].legend()

axs[0, 1].semilogy(c15_SD_p, c15_SD_e, linestyle='-', color='black', label='SD')
axs[0, 1].semilogy(c15_DT_p, c15_DT_e, linestyle='-', color='brown', label='SDT')
axs[0, 1].semilogy(c15_t3_p, c15_t3_e, linestyle='-', color='red', label='t3')
axs[0, 1].semilogy(c15_t2_p, c15_t2_e, linestyle='-', color='green', label='t2')
axs[0, 1].semilogy(c15_t1_p, c15_t1_e, linestyle='-', color='blue', label='t1')
axs[0, 1].semilogy(c15_t4_p, c15_t4_e, linestyle='-', color='purple', label='t4')
axs[0, 1].axhline(y=1.6e-3, color='gray', linestyle=':', linewidth=1, label='Chemical Accuracy')
# axs[0, 1].set_title('log10 Energy vs params')
axs[0, 1].set_xlabel('$N_{par}$')
axs[0, 1].set_ylabel('Energy Error / $mE_{h}$')
# axs[0, 1].legend()

axs[1, 0].loglog(c15_SD_m, c15_SD_e, linestyle='-', color='black', label='SD')
axs[1, 0].loglog(c15_DT_m, c15_DT_e, linestyle='-', color='brown', label='SDT')
axs[1, 0].loglog(c15_t3_m, c15_t3_e, linestyle='-', color='red', label='t3')
axs[1, 0].loglog(c15_t2_m, c15_t2_e, linestyle='-', color='green', label='t2')
axs[1, 0].loglog(c15_t1_m, c15_t1_e, linestyle='-', color='blue', label='t1')
axs[1, 0].loglog(c15_t4_m, c15_t4_e, linestyle='-', color='purple', label='t4')
axs[1, 0].axhline(y=1.6e-3, color='gray', linestyle=':', linewidth=1, label='Chemical Accuracy')
# axs[1, 0].set_title('log10 Energy vs pauli')
axs[1, 0].set_xlabel('$N_{meas}$')
axs[1, 0].set_ylabel('Energy Error / $mE_{h}$')
# axs[1, 0].legend()

axs[1, 1].loglog(c15_SD_c, c15_SD_e, linestyle='-', color='black', label='SD')
axs[1, 1].loglog(c15_DT_c, c15_DT_e, linestyle='-', color='brown', label='SDT')
axs[1, 1].loglog(c15_t3_c, c15_t3_e, linestyle='-', color='red', label='t3')
axs[1, 1].loglog(c15_t2_c, c15_t2_e, linestyle='-', color='green', label='t2')
axs[1, 1].loglog(c15_t1_c, c15_t1_e, linestyle='-', color='blue', label='t1')
axs[1, 1].loglog(c15_t4_c, c15_t4_e, linestyle='-', color='purple', label='t4')
axs[1, 1].axhline(y=1.6e-3, color='gray', linestyle=':', linewidth=1, label='Chemical Accuracy')
# axs[1, 1].set_title('log10 Energy vs cnot')
axs[1, 1].set_xlabel('$N_{CNOT}$')
axs[1, 1].set_ylabel('Energy Error / $mE_{h}$')
# axs[1, 1].legend()

# fig.suptitle("Chain 1.0A", fontsize=16)
# Adjust layout and show plot
plt.tight_layout()
plt.show()

# %%
# Create 2x2 subplot grid
fig, axs = plt.subplots(2, 2, figsize=(12, 10))

axs[0, 0].semilogy(r15_SD_b, r15_SD_e, linestyle='-', color='black', label='SD')
axs[0, 0].semilogy(r15_DT_b, r15_DT_e, linestyle='-', color='brown', label='SDT')
axs[0, 0].semilogy(r15_t3_b, r15_t3_e, linestyle='-', color='red', label='t3')
axs[0, 0].semilogy(r15_t2_b, r15_t2_e, linestyle='-', color='green', label='t2')
axs[0, 0].semilogy(r15_t1_b, r15_t1_e, linestyle='-', color='blue', label='t1')
axs[0, 0].semilogy(r15_t4_b, r15_t4_e, linestyle='-', color='purple', label='t4')
axs[0, 0].axhline(y=1.6e-3, color='gray', linestyle=':', linewidth=1, label='Chemical Accuracy')
# axs[0, 0].set_title('log10 Energy vs beta')
axs[0, 0].set_xlabel(r'$ \beta $(a. u.)')
axs[0, 0].set_ylabel('Energy Error / $mE_{h}$')
# axs[0, 0].legend()

axs[0, 1].semilogy(r15_SD_p, r15_SD_e, linestyle='-', color='black', label='SD')
axs[0, 1].semilogy(r15_DT_p, r15_DT_e, linestyle='-', color='brown', label='SDT')
axs[0, 1].semilogy(r15_t3_p, r15_t3_e, linestyle='-', color='red', label='t3')
axs[0, 1].semilogy(r15_t2_p, r15_t2_e, linestyle='-', color='green', label='t2')
axs[0, 1].semilogy(r15_t1_p, r15_t1_e, linestyle='-', color='blue', label='t1')
axs[0, 1].semilogy(r15_t4_p, r15_t4_e, linestyle='-', color='purple', label='t4')
axs[0, 1].axhline(y=1.6e-3, color='gray', linestyle=':', linewidth=1, label='Chemical Accuracy')
# axs[0, 1].set_title('log10 Energy vs params')
axs[0, 1].set_xlabel('$N_{par}$')
axs[0, 1].set_ylabel('Energy Error / $mE_{h}$')
# axs[0, 1].legend()

axs[1, 0].loglog(r15_SD_m, r15_SD_e, linestyle='-', color='black', label='SD')
axs[1, 0].loglog(r15_DT_m, r15_DT_e, linestyle='-', color='brown', label='SDT')
axs[1, 0].loglog(r15_t3_m, r15_t3_e, linestyle='-', color='red', label='t3')
axs[1, 0].loglog(r15_t2_m, r15_t2_e, linestyle='-', color='green', label='t2')
axs[1, 0].loglog(r15_t1_m, r15_t1_e, linestyle='-', color='blue', label='t1')
axs[1, 0].loglog(r15_t4_m, r15_t4_e, linestyle='-', color='purple', label='t4')
axs[1, 0].axhline(y=1.6e-3, color='gray', linestyle=':', linewidth=1, label='Chemical Accuracy')
# axs[1, 0].set_title('log10 Energy vs pauli')
axs[1, 0].set_xlabel('$N_{meas}$')
axs[1, 0].set_ylabel('Energy Error / $mE_{h}$')
# axs[1, 0].legend()

axs[1, 1].loglog(r15_SD_c, r15_SD_e, linestyle='-', color='black', label='SD')
axs[1, 1].loglog(r15_DT_c, r15_DT_e, linestyle='-', color='brown', label='SDT')
axs[1, 1].loglog(r15_t3_c, r15_t3_e, linestyle='-', color='red', label='t3')
axs[1, 1].loglog(r15_t2_c, r15_t2_e, linestyle='-', color='green', label='t2')
axs[1, 1].loglog(r15_t1_c, r15_t1_e, linestyle='-', color='blue', label='t1')
axs[1, 1].loglog(r15_t4_c, r15_t4_e, linestyle='-', color='purple', label='t4')
axs[1, 1].axhline(y=1.6e-3, color='gray', linestyle=':', linewidth=1, label='Chemical Accuracy')
# axs[1, 1].set_title('log10 Energy vs cnot')
axs[1, 1].set_xlabel('$N_{CNOT}$')
axs[1, 1].set_ylabel('Energy Error / $mE_{h}$')
# axs[1, 1].legend()

# fig.suptitle("Chain 1.0A", fontsize=16)
# Adjust layout and show plot
plt.tight_layout()
plt.show()

# %%
# Create 2x2 subplot grid
fig, axs = plt.subplots(2, 2, figsize=(12, 10))

axs[0, 0].semilogy(s15_SD_b, s15_SD_e, linestyle='-', color='black', label='SD')
axs[0, 0].semilogy(s15_DT_b, s15_DT_e, linestyle='-', color='brown', label='SDT')
axs[0, 0].semilogy(s15_t3_b, s15_t3_e, linestyle='-', color='red', label='t3')
axs[0, 0].semilogy(s15_t2_b, s15_t2_e, linestyle='-', color='green', label='t2')
axs[0, 0].semilogy(s15_t1_b, s15_t1_e, linestyle='-', color='blue', label='t1')
axs[0, 0].semilogy(s15_t4_b, s15_t4_e, linestyle='-', color='purple', label='t4')
axs[0, 0].axhline(y=1.6e-3, color='gray', linestyle=':', linewidth=1, label='Chemical Accuracy')
# axs[0, 0].set_title('log10 Energy vs beta')
axs[0, 0].set_xlabel(r'$ \beta $(a. u.)')
axs[0, 0].set_ylabel('Energy Error / $mE_{h}$')
# axs[0, 0].legend()

axs[0, 1].semilogy(s15_SD_p, s15_SD_e, linestyle='-', color='black', label='SD')
axs[0, 1].semilogy(s15_DT_p, s15_DT_e, linestyle='-', color='brown', label='SDT')
axs[0, 1].semilogy(s15_t3_p, s15_t3_e, linestyle='-', color='red', label='t3')
axs[0, 1].semilogy(s15_t2_p, s15_t2_e, linestyle='-', color='green', label='t2')
axs[0, 1].semilogy(s15_t1_p, s15_t1_e, linestyle='-', color='blue', label='t1')
axs[0, 1].semilogy(s15_t4_p, s15_t4_e, linestyle='-', color='purple', label='t4')
axs[0, 1].axhline(y=1.6e-3, color='gray', linestyle=':', linewidth=1, label='Chemical Accuracy')
# axs[0, 1].set_title('log10 Energy vs params')
axs[0, 1].set_xlabel('$N_{par}$')
axs[0, 1].set_ylabel('Energy Error / $mE_{h}$')
# axs[0, 1].legend()

axs[1, 0].loglog(s15_SD_m, s15_SD_e, linestyle='-', color='black', label='SD')
axs[1, 0].loglog(s15_DT_m, s15_DT_e, linestyle='-', color='brown', label='SDT')
axs[1, 0].loglog(s15_t3_m, s15_t3_e, linestyle='-', color='red', label='t3')
axs[1, 0].loglog(s15_t2_m, s15_t2_e, linestyle='-', color='green', label='t2')
axs[1, 0].loglog(s15_t1_m, s15_t1_e, linestyle='-', color='blue', label='t1')
axs[1, 0].loglog(s15_t4_m, s15_t4_e, linestyle='-', color='purple', label='t4')
axs[1, 0].axhline(y=1.6e-3, color='gray', linestyle=':', linewidth=1, label='Chemical Accuracy')
# axs[1, 0].set_title('log10 Energy vs pauli')
axs[1, 0].set_xlabel('$N_{meas}$')
axs[1, 0].set_ylabel('Energy Error / $mE_{h}$')
# axs[1, 0].legend()

axs[1, 1].loglog(s15_SD_c, s15_SD_e, linestyle='-', color='black', label='SD')
axs[1, 1].loglog(s15_DT_c, s15_DT_e, linestyle='-', color='brown', label='SDT')
axs[1, 1].loglog(s15_t3_c, s15_t3_e, linestyle='-', color='red', label='t3')
axs[1, 1].loglog(s15_t2_c, s15_t2_e, linestyle='-', color='green', label='t2')
axs[1, 1].loglog(s15_t1_c, s15_t1_e, linestyle='-', color='blue', label='t1')
axs[1, 1].loglog(s15_t4_c, s15_t4_e, linestyle='-', color='purple', label='t4')
axs[1, 1].axhline(y=1.6e-3, color='gray', linestyle=':', linewidth=1, label='Chemical Accuracy')
# axs[1, 1].set_title('log10 Energy vs cnot')
axs[1, 1].set_xlabel('$N_{CNOT}$')
axs[1, 1].set_ylabel('Energy Error / $mE_{h}$')
# axs[1, 1].legend()

# fig.suptitle("Chain 1.0A", fontsize=16)
# Adjust layout and show plot
plt.tight_layout()
plt.show()
